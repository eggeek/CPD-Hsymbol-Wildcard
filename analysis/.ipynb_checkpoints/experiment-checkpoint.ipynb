# %%
from utilities import *
import pandas as pd
import os

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def mtype(mapname):
    if mapname.startswith('room'):
        return 'room'
    elif mapname.startswith('maze'):
        return 'maze'
    elif mapname.startswith('random'):
        return 'random'
    else:
        return 'game'

def add_columns(df):
    df.insert(2, "step-cost", df['tcost'] / df['steps'])
    df.insert(2, "step-access", df["access"] / df['steps'])
    df.insert(2, "diff", df["distance"] - df["expect"])
    df.insert(2, "step-diff", df["diff"] / df["steps"])
    df.insert(2, "ratio", df["diff"] / df["expect"])

# %%
# load cpd
prefix = '../outputs/cpd/'
h = [prefix + i for i in os.listdir(prefix)]

cpd = load_files(h)
add_columns(cpd)
cpd.head()
# Out:
# ../outputs/cpd/lt_darktown.map-3-dfs-c4-inv.txt
# ../outputs/cpd/ht_chantry.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz107d.map-3-dfs-c2-inv.txt
# ../outputs/cpd/orz301d.map-3-dfs-c8.txt
# ../outputs/cpd/orz102d.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz103d.map-3-dfs-c64-inv.txt
# ../outputs/cpd/ca_cave.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz700d.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ht_bartrand_n.map-3-dfs-c16.txt
# ../outputs/cpd/dr_slavers.map-3-dfs-c2-inv.txt
# ../outputs/cpd/ht_bartrand_n.map-3-dfs-opt.txt
# ../outputs/cpd/lt_0_lowtown_a2.map-3-dfs-opt-inv.txt
# ../outputs/cpd/BrokenSteppes.map-3-dfs-c2-inv.txt
# ../outputs/cpd/Archipelago.map-3-dfs-c8-inv.txt
# ../outputs/cpd/lt_backalley_g.map-3-dfs-c2-inv.txt
# ../outputs/cpd/lt_ruinedhouse_n.map-3-dfs-c2-inv.txt
# ../outputs/cpd/dr_0_deeproads.map-3-dfs-c2-inv.txt
# ../outputs/cpd/ca_caverns2prc.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz103d.map-3-dfs-c16-inv.txt
# ../outputs/cpd/orz500d.map-3-dfs-c64.txt
# ../outputs/cpd/w_encounter1.map-3-dfs-c8-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks_n.map-3-dfs-c32.txt
# ../outputs/cpd/lt_hangedman.map-3-dfs-c8-inv.txt
# ../outputs/cpd/ht_chantry_n.map-3-dfs-c8.txt
# ../outputs/cpd/orz800d.map-3-dfs-c2-inv.txt
# ../outputs/cpd/ca_caverns2.map-3-dfs-c32.txt
# ../outputs/cpd/Aftershock.map-3-dfs-c2.txt
# ../outputs/cpd/ht_mansion2b.map-3-dfs-c8-inv.txt
# ../outputs/cpd/ht_bartrand_n.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_house.map-3-dfs-c4.txt
# ../outputs/cpd/ca_caverns1.map-3-dfs-c2-inv.txt
# ../outputs/cpd/orz702d.map-3-dfs-c16.txt
# ../outputs/cpd/orz702d.map-3-dfs-opt.txt
# ../outputs/cpd/lt_undercityserialkiller.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks_a3.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz201d.map-3-dfs-c2-inv.txt
# ../outputs/cpd/ca_cave.map-3-dfs-c2-inv.txt
# ../outputs/cpd/lt_backalley_g.map-3-dfs-c64.txt
# ../outputs/cpd/orz901d.map-3-dfs-c64.txt
# ../outputs/cpd/orz700d.map-3-dfs-c2-inv.txt
# ../outputs/cpd/orz102d.map-3-dfs-c32.txt
# ../outputs/cpd/ht_chantry.map-3-dfs-c4.txt
# ../outputs/cpd/random-100-33.map-3-dfs-c2-inv.txt
# ../outputs/cpd/lt_0_lowtown_a3_n_c.map-3-dfs-c2-inv.txt
# ../outputs/cpd/w_blightlands.map-3-dfs-c8.txt
# ../outputs/cpd/room-400-40.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz201d.map-3-dfs-c8.txt
# ../outputs/cpd/lt_gallowstemplar_n.map-3-dfs-c16-inv.txt
# ../outputs/cpd/dr_primevalentrance.map-3-dfs-c32.txt
# ../outputs/cpd/ht_keep_n.map-3-dfs-c4.txt
# ../outputs/cpd/orz999d.map-3-dfs-c2-inv.txt
# ../outputs/cpd/orz300d.map-3-dfs-opt-inv.txt
# ../outputs/cpd/orz302d.map-3-dfs-c2-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks_a3.map-3-dfs-c32-inv.txt
# ../outputs/cpd/ca_cavern1_haunted.map-3-dfs-c2.txt
# ../outputs/cpd/AcrosstheCape.map-3-dfs-c2-inv.txt
# ../outputs/cpd/ca_caverns2prc.map-3-dfs-c16.txt
# ../outputs/cpd/lt_0_lowtown_a2_n_c.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ca_caverns2prc.map-3-dfs-opt.txt
# ../outputs/cpd/orz700d.map-3-dfs-c8.txt
# ../outputs/cpd/room-400-40.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_gallowstemplar_n.map-3-dfs-c64-inv.txt
# ../outputs/cpd/w_woundedcoast.map-3-dfs-c2.txt
# ../outputs/cpd/orz704d.map-3-dfs-c64.txt
# ../outputs/cpd/ht_chantry.map-3-dfs-opt.txt
# ../outputs/cpd/ht_chantry.map-3-dfs-c16.txt
# ../outputs/cpd/BigGameHunters.map-3-dfs-c16.txt
# ../outputs/cpd/lt_gallowsprison_n.map-3-dfs-c4.txt
# ../outputs/cpd/ht_bartrand_n.map-3-dfs-c4.txt
# ../outputs/cpd/orz000d.map-3-dfs-c64.txt
# ../outputs/cpd/lt_house.map-3-dfs-c32-inv.txt
# ../outputs/cpd/BigGameHunters.map-3-dfs-opt.txt
# ../outputs/cpd/ht_mansion2.map-3-dfs-opt.txt
# ../outputs/cpd/lt_gallowsprison_n.map-3-dfs-c32-inv.txt
# ../outputs/cpd/ht_mansion2.map-3-dfs-c16.txt
# ../outputs/cpd/ht_bartrand_n.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_0_lowtown_n.map-3-dfs-c8-inv.txt
# ../outputs/cpd/dr_0_deeproads.map-3-dfs-c4.txt
# ../outputs/cpd/lt_gallowstemplar_n.map-3-dfs-c8.txt
# ../outputs/cpd/BlastFurnace.map-3-dfs-c64.txt
# ../outputs/cpd/lt_0_lowtown.map-3-dfs-c64.txt
# ../outputs/cpd/dr_0_deeproads.map-3-dfs-c32.txt
# ../outputs/cpd/Aurora.map-3-dfs-c8.txt
# ../outputs/cpd/ht_keep_n.map-3-dfs-c64-inv.txt
# ../outputs/cpd/BlastFurnace.map-3-dfs-c16-inv.txt
# ../outputs/cpd/ht_keep_n.map-3-dfs-c32.txt
# ../outputs/cpd/orz703d.map-3-dfs-c32.txt
# ../outputs/cpd/orz103d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/maze-400-4.map-3-dfs-opt.txt
# ../outputs/cpd/lt_0_lowtown_a3_n_c.map-3-dfs-c16-inv.txt
# ../outputs/cpd/maze-400-4.map-3-dfs-c16.txt
# ../outputs/cpd/orz601d.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ht_0_hightown_n.map-3-dfs-c8.txt
# ../outputs/cpd/orz000d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz105d.map-3-dfs-c32-inv.txt
# ../outputs/cpd/dr_slavers.map-3-dfs-opt.txt
# ../outputs/cpd/lt_shop.map-3-dfs-c2.txt
# ../outputs/cpd/dr_slavers.map-3-dfs-c16.txt
# ../outputs/cpd/lt_gallowstemplar.map-3-dfs-c4-inv.txt
# ../outputs/cpd/w_encounter2.map-3-dfs-c4-inv.txt
# ../outputs/cpd/w_bonepit.map-3-dfs-c2-inv.txt
# ../outputs/cpd/lt_0_lowtown_a2_n_c.map-3-dfs-c2.txt
# ../outputs/cpd/orz103d.map-3-dfs-c16.txt
# ../outputs/cpd/ca_cavern1_haunted.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz103d.map-3-dfs-opt.txt
# ../outputs/cpd/orz304d.map-3-dfs-c8.txt
# ../outputs/cpd/w_encounter2.map-3-dfs-c64-inv.txt
# ../outputs/cpd/ca_caverns1.map-3-dfs-c32-inv.txt
# ../outputs/cpd/dr_primevalentrance.map-3-dfs-c8-inv.txt
# ../outputs/cpd/w_woundedcoast.map-3-dfs-c4-inv.txt
# ../outputs/cpd/ht_0_hightown_a3.map-3-dfs-c4-inv.txt
# ../outputs/cpd/w_sundermount.map-3-dfs-opt.txt
# ../outputs/cpd/lt_0_lowtown_n.map-3-dfs-c64.txt
# ../outputs/cpd/ht_0_hightown_n.map-3-dfs-c8-inv.txt
# ../outputs/cpd/w_encounter2.map-3-dfs-c16-inv.txt
# ../outputs/cpd/w_sundermount.map-3-dfs-c16.txt
# ../outputs/cpd/orz999d.map-3-dfs-c64.txt
# ../outputs/cpd/lt_undercitydungeon.map-3-dfs-c8.txt
# ../outputs/cpd/orz601d.map-3-dfs-c64.txt
# ../outputs/cpd/ca_caverns1_mines.map-3-dfs-c4-inv.txt
# ../outputs/cpd/w_bonepitmining_a2.map-3-dfs-c2.txt
# ../outputs/cpd/ht_0_hightown.map-3-dfs-c16.txt
# ../outputs/cpd/ht_0_hightown.map-3-dfs-opt.txt
# ../outputs/cpd/lt_gallowsprison_n.map-3-dfs-c2-inv.txt
# ../outputs/cpd/ht_mansion2b.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ca_caverns1_mines.map-3-dfs-c32.txt
# ../outputs/cpd/orz105d.map-3-dfs-c64.txt
# ../outputs/cpd/orz900d.map-3-dfs-c4-inv.txt
# ../outputs/cpd/w_encounter2.map-3-dfs-c4.txt
# ../outputs/cpd/maze-400-4.map-3-dfs-c8.txt
# ../outputs/cpd/lt_0_lowtown_a3_n_c.map-3-dfs-c64-inv.txt
# ../outputs/cpd/BlastFurnace.map-3-dfs-c64-inv.txt
# ../outputs/cpd/dr_dungeon.map-3-dfs-c64.txt
# ../outputs/cpd/lt_gallowstemplar.map-3-dfs-c4.txt
# ../outputs/cpd/dr_primevaltomb.map-3-dfs-c2.txt
# ../outputs/cpd/orz101d.map-3-dfs-c8.txt
# ../outputs/cpd/Aftershock.map-3-dfs-c16.txt
# ../outputs/cpd/ht_0_hightown_n.map-3-dfs-c32-inv.txt
# ../outputs/cpd/w_bonepitmining_a2.map-3-dfs-c4-inv.txt
# ../outputs/cpd/Aftershock.map-3-dfs-opt.txt
# ../outputs/cpd/ht_keep_n.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_hangedman.map-3-dfs-c8.txt
# ../outputs/cpd/lt_gallowstemplar_f.map-3-dfs-c2.txt
# ../outputs/cpd/orz201d.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_gallowscourtyard_n.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz301d.map-3-dfs-c4-inv.txt
# ../outputs/cpd/ht_0_hightown_a2.map-3-dfs-c64-inv.txt
# ../outputs/cpd/lt_gallowscourtyard_n.map-3-dfs-c8-inv.txt
# ../outputs/cpd/ca_caverns1_mines.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ht_0_hightown_a3.map-3-dfs-c4.txt
# ../outputs/cpd/ht_keep.map-3-dfs-c16-inv.txt
# ../outputs/cpd/orz704d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/lt_0_lowtown_a2.map-3-dfs-c8-inv.txt
# ../outputs/cpd/lt_hangedman_n.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz500d.map-3-dfs-c8.txt
# ../outputs/cpd/lt_gallowstemplar_f.map-3-dfs-c64-inv.txt
# ../outputs/cpd/ca_caverns2prc.map-3-dfs-c4-inv.txt
# ../outputs/cpd/ht_playershouse_n.map-3-dfs-c2.txt
# ../outputs/cpd/orz203d.map-3-dfs-c32.txt
# ../outputs/cpd/orz703d.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_house.map-3-dfs-c64.txt
# ../outputs/cpd/ht_store.map-3-dfs-c16-inv.txt
# ../outputs/cpd/BigGameHunters.map-3-dfs-c32-inv.txt
# ../outputs/cpd/w_sundermount.map-3-dfs-c64-inv.txt
# ../outputs/cpd/Brushfire.map-3-dfs-c2.txt
# ../outputs/cpd/w_sundermount.map-3-dfs-c16-inv.txt
# ../outputs/cpd/BlackLotus.map-3-dfs-c32.txt
# ../outputs/cpd/dr_slavers.map-3-dfs-c8.txt
# ../outputs/cpd/ht_store.map-3-dfs-c64-inv.txt
# ../outputs/cpd/w_sundermount.map-3-dfs-c8.txt
# ../outputs/cpd/lt_hangedman.map-3-dfs-c32.txt
# ../outputs/cpd/w_blightlands.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz999d.map-3-dfs-opt-inv.txt
# ../outputs/cpd/Aftershock.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_gallowstemplar_f.map-3-dfs-c16-inv.txt
# ../outputs/cpd/ht_keep.map-3-dfs-c64-inv.txt
# ../outputs/cpd/BlackLotus.map-3-dfs-c2-inv.txt
# ../outputs/cpd/lt_gallowscourtyard.map-3-dfs-opt-inv.txt
# ../outputs/cpd/Backwoods.map-3-dfs-c16.txt
# ../outputs/cpd/lt_0_lowtown_a2_n.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz301d.map-3-dfs-c64.txt
# ../outputs/cpd/Backwoods.map-3-dfs-opt.txt
# ../outputs/cpd/ht_playershouse_n.map-3-dfs-c2-inv.txt
# ../outputs/cpd/ht_0_hightown_a2.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_hangedman_n.map-3-dfs-c8-inv.txt
# ../outputs/cpd/lt_gallowscourtyard_n.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_warehouse_n.map-3-dfs-c2.txt
# ../outputs/cpd/orz200d.map-3-dfs-c32.txt
# ../outputs/cpd/ca_caverns1_mines.map-3-dfs-c8.txt
# ../outputs/cpd/orz702d.map-3-dfs-c2-inv.txt
# ../outputs/cpd/ht_keep_n.map-3-dfs-c2-inv.txt
# ../outputs/cpd/ht_keep.map-3-dfs-c64.txt
# ../outputs/cpd/orz900d.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks.map-3-dfs-c32-inv.txt
# ../outputs/cpd/BlackLotus.map-3-dfs-opt-inv.txt
# ../outputs/cpd/orz203d.map-3-dfs-c2-inv.txt
# ../outputs/cpd/lt_foundry_n.map-3-dfs-opt-inv.txt
# ../outputs/cpd/orz304d.map-3-dfs-opt.txt
# ../outputs/cpd/orz300d.map-3-dfs-c8.txt
# ../outputs/cpd/orz304d.map-3-dfs-c16.txt
# ../outputs/cpd/maze-400-4.map-3-dfs-c64-inv.txt
# ../outputs/cpd/dr_primevaltomb.map-3-dfs-c16-inv.txt
# ../outputs/cpd/w_encounter2_camp.map-3-dfs-c8.txt
# ../outputs/cpd/ht_brothel_n.map-3-dfs-c16-inv.txt
# ../outputs/cpd/orz300d.map-3-dfs-c2-inv.txt
# ../outputs/cpd/lt_shop.map-3-dfs-c64.txt
# ../outputs/cpd/ht_mansion2.map-3-dfs-c8.txt
# ../outputs/cpd/orz601d.map-3-dfs-c2-inv.txt
# ../outputs/cpd/orz107d.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks_a3_n.map-3-dfs-c64.txt
# ../outputs/cpd/orz302d.map-3-dfs-c64.txt
# ../outputs/cpd/orz704d.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ht_mansion2b.map-3-dfs-c8.txt
# ../outputs/cpd/orz106d.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz107d.map-3-dfs-c64-inv.txt
# ../outputs/cpd/dr_primevaltomb.map-3-dfs-c2-inv.txt
# ../outputs/cpd/orz105d.map-3-dfs-c8.txt
# ../outputs/cpd/lt_hangedman_n.map-3-dfs-c64.txt
# ../outputs/cpd/dr_primevaltomb.map-3-dfs-c64-inv.txt
# ../outputs/cpd/ht_brothel_n.map-3-dfs-c64-inv.txt
# ../outputs/cpd/lt_warehouse.map-3-dfs-c32.txt
# ../outputs/cpd/maze-400-4.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_warehouse.map-3-dfs-c8-inv.txt
# ../outputs/cpd/w_bonepitmining_a2.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_0_lowtown_a2_n_c.map-3-dfs-c8-inv.txt
# ../outputs/cpd/lt_house.map-3-dfs-c2.txt
# ../outputs/cpd/orz901d.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz601d.map-3-dfs-c8.txt
# ../outputs/cpd/ht_chantry_n.map-3-dfs-c2-inv.txt
# ../outputs/cpd/orz900d.map-3-dfs-c64-inv.txt
# ../outputs/cpd/w_encounter2_camp.map-3-dfs-c4-inv.txt
# ../outputs/cpd/ht_brothel_n.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz000d.map-3-dfs-c32-inv.txt
# ../outputs/cpd/lt_gallowscourtyard.map-3-dfs-c16.txt
# ../outputs/cpd/Aftershock.map-3-dfs-c4.txt
# ../outputs/cpd/lt_backalley_n.map-3-dfs-c32-inv.txt
# ../outputs/cpd/lt_gallowscourtyard.map-3-dfs-opt.txt
# ../outputs/cpd/random-400-33.map-3-dfs-c64-inv.txt
# ../outputs/cpd/lt_shop.map-3-dfs-c4-inv.txt
# ../outputs/cpd/orz105d.map-3-dfs-c2-inv.txt
# ../outputs/cpd/lt_undercityserialkiller.map-3-dfs-c4-inv.txt
# ../outputs/cpd/w_bonepitdestroyed_a3.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_undercityserialkiller.map-3-dfs-c32.txt
# ../outputs/cpd/orz100d.map-3-dfs-opt.txt
# ../outputs/cpd/orz100d.map-3-dfs-c16.txt
# ../outputs/cpd/orz200d.map-3-dfs-c8.txt
# ../outputs/cpd/maze-100-1.map-3-dfs-c4-inv.txt
# ../outputs/cpd/Archipelago.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ht_chantry.map-3-dfs-c2.txt
# ../outputs/cpd/ht_mansion2.map-3-dfs-c8-inv.txt
# ../outputs/cpd/lt_gallowstemplar.map-3-dfs-c64-inv.txt
# ../outputs/cpd/room-400-40.map-3-dfs-c16.txt
# ../outputs/cpd/room-400-40.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz700d.map-3-dfs-c32.txt
# ../outputs/cpd/room-400-40.map-3-dfs-opt.txt
# ../outputs/cpd/ht_keep_n.map-3-dfs-c2.txt
# ../outputs/cpd/orz701d.map-3-dfs-c8.txt
# ../outputs/cpd/orz901d.map-3-dfs-c2-inv.txt
# ../outputs/cpd/Archipelago.map-3-dfs-c64.txt
# ../outputs/cpd/orz106d.map-3-dfs-c64.txt
# ../outputs/cpd/lt_gallowstemplar.map-3-dfs-c16-inv.txt
# ../outputs/cpd/ca_cavern1_haunted.map-3-dfs-c4.txt
# ../outputs/cpd/lt_0_lowtown_docks_n.map-3-dfs-c2-inv.txt
# ../outputs/cpd/w_woundedcoast.map-3-dfs-c4.txt
# ../outputs/cpd/ht_chantry_n.map-3-dfs-c16.txt
# ../outputs/cpd/orz304d.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ht_chantry_n.map-3-dfs-opt.txt
# ../outputs/cpd/w_bonepitdestroyed_a3.map-3-dfs-c64-inv.txt
# ../outputs/cpd/lt_gallowsprison_n.map-3-dfs-c2.txt
# ../outputs/cpd/ht_keep.map-3-dfs-c8.txt
# ../outputs/cpd/ht_bartrand_n.map-3-dfs-c2.txt
# ../outputs/cpd/ArcticStation.map-3-dfs-c4-inv.txt
# ../outputs/cpd/random-400-33.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_house.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks.map-3-dfs-c64.txt
# ../outputs/cpd/dr_0_deeproads.map-3-dfs-c2.txt
# ../outputs/cpd/lt_gallowstemplar_f.map-3-dfs-c64.txt
# ../outputs/cpd/ca_caverns2.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_gallowstemplar_f.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz101d.map-3-dfs-c32.txt
# ../outputs/cpd/ht_mansion2.map-3-dfs-c16-inv.txt
# ../outputs/cpd/orz303d.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_0_lowtown_a3_n_c.map-3-dfs-c16.txt
# ../outputs/cpd/Backwoods.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_0_lowtown_a3_n_c.map-3-dfs-opt.txt
# ../outputs/cpd/lt_gamlenshouse_n.map-3-dfs-c8.txt
# ../outputs/cpd/orz200d.map-3-dfs-c4-inv.txt
# ../outputs/cpd/ArcticStation.map-3-dfs-c16.txt
# ../outputs/cpd/orz304d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/ArcticStation.map-3-dfs-opt.txt
# ../outputs/cpd/orz701d.map-3-dfs-opt.txt
# ../outputs/cpd/Backwoods.map-3-dfs-c16-inv.txt
# ../outputs/cpd/ht_mansion_n.map-3-dfs-c2-inv.txt
# ../outputs/cpd/orz701d.map-3-dfs-c16.txt
# ../outputs/cpd/lt_shop.map-3-dfs-c4.txt
# ../outputs/cpd/dr_slavers.map-3-dfs-c16-inv.txt
# ../outputs/cpd/orz701d.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_undercitydungeon.map-3-dfs-c2-inv.txt
# ../outputs/cpd/lt_backalley_g.map-3-dfs-c8.txt
# ../outputs/cpd/orz100d.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_0_lowtown_a2_n_c.map-3-dfs-c4.txt
# ../outputs/cpd/BrokenSteppes.map-3-dfs-c32.txt
# ../outputs/cpd/orz703d.map-3-dfs-opt-inv.txt
# ../outputs/cpd/Archipelago.map-3-dfs-c8.txt
# ../outputs/cpd/orz800d.map-3-dfs-c32-inv.txt
# ../outputs/cpd/lt_darktown.map-3-dfs-c8.txt
# ../outputs/cpd/orz101d.map-3-dfs-c32-inv.txt
# ../outputs/cpd/maze-100-1.map-3-dfs-c32.txt
# ../outputs/cpd/ca_cavern1_haunted.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz100d.map-3-dfs-c64-inv.txt
# ../outputs/cpd/dr_slavers.map-3-dfs-c64-inv.txt
# ../outputs/cpd/lt_undercitydungeon.map-3-dfs-c64.txt
# ../outputs/cpd/random-400-33.map-3-dfs-c8-inv.txt
# ../outputs/cpd/w_bonepitmining_a2.map-3-dfs-opt.txt
# ../outputs/cpd/lt_0_lowtown_docks_a3_n.map-3-dfs-c2-inv.txt
# ../outputs/cpd/Backwoods.map-3-dfs-c64-inv.txt
# ../outputs/cpd/w_bonepitmining_a2.map-3-dfs-c16.txt
# ../outputs/cpd/w_bonepitmining_a2.map-3-dfs-c4.txt
# ../outputs/cpd/w_bonepit.map-3-dfs-c32.txt
# ../outputs/cpd/w_encounter1.map-3-dfs-c8.txt
# ../outputs/cpd/w_encounter2.map-3-dfs-c2.txt
# ../outputs/cpd/lt_gallowsprison_n.map-3-dfs-c32.txt
# ../outputs/cpd/lt_0_lowtown_a2_n.map-3-dfs-c8-inv.txt
# ../outputs/cpd/w_blightlands.map-3-dfs-opt-inv.txt
# ../outputs/cpd/BigGameHunters.map-3-dfs-c4-inv.txt
# ../outputs/cpd/ht_mansion2.map-3-dfs-c64-inv.txt
# ../outputs/cpd/ht_mansion_n.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz100d.map-3-dfs-c8.txt
# ../outputs/cpd/lt_gallowstemplar.map-3-dfs-c2.txt
# ../outputs/cpd/orz800d.map-3-dfs-c32.txt
# ../outputs/cpd/ht_store.map-3-dfs-c32.txt
# ../outputs/cpd/dr_primevaltomb.map-3-dfs-c4.txt
# ../outputs/cpd/ht_chantry.map-3-dfs-c2-inv.txt
# ../outputs/cpd/w_encounter2_camp.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_foundry_n.map-3-dfs-c64.txt
# ../outputs/cpd/Brushfire.map-3-dfs-c16-inv.txt
# ../outputs/cpd/ht_playershouse_n.map-3-dfs-c32.txt
# ../outputs/cpd/lt_ruinedhouse_n.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz101d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/ht_mansion2b.map-3-dfs-c32.txt
# ../outputs/cpd/lt_gallowstemplar_f.map-3-dfs-c4.txt
# ../outputs/cpd/lt_0_lowtown_a2_n.map-3-dfs-c16.txt
# ../outputs/cpd/ca_cave.map-3-dfs-opt.txt
# ../outputs/cpd/orz201d.map-3-dfs-c16.txt
# ../outputs/cpd/w_woundedcoast.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ca_cave.map-3-dfs-c16.txt
# ../outputs/cpd/lt_0_lowtown_a2_n.map-3-dfs-opt.txt
# ../outputs/cpd/orz201d.map-3-dfs-opt.txt
# ../outputs/cpd/lt_0_lowtown_docks.map-3-dfs-c8.txt
# ../outputs/cpd/ht_0_hightown_a3.map-3-dfs-c2.txt
# ../outputs/cpd/ht_playershouse_n.map-3-dfs-c4.txt
# ../outputs/cpd/lt_undercityserialkiller.map-3-dfs-c8.txt
# ../outputs/cpd/orz500d.map-3-dfs-c16-inv.txt
# ../outputs/cpd/w_blightlands.map-3-dfs-c64.txt
# ../outputs/cpd/lt_backalley_g.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_undercitydungeon.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz106d.map-3-dfs-c4-inv.txt
# ../outputs/cpd/dr_dungeon.map-3-dfs-c8-inv.txt
# ../outputs/cpd/w_encounter1.map-3-dfs-c32.txt
# ../outputs/cpd/dr_dungeon.map-3-dfs-c32-inv.txt
# ../outputs/cpd/Brushfire.map-3-dfs-c4.txt
# ../outputs/cpd/orz000d.map-3-dfs-c8.txt
# ../outputs/cpd/Brushfire.map-3-dfs-c8-inv.txt
# ../outputs/cpd/random-100-33.map-3-dfs-c32.txt
# ../outputs/cpd/ht_brothel_n.map-3-dfs-opt.txt
# ../outputs/cpd/orz500d.map-3-dfs-c64-inv.txt
# ../outputs/cpd/ht_brothel_n.map-3-dfs-c16.txt
# ../outputs/cpd/w_encounter2_camp.map-3-dfs-c16.txt
# ../outputs/cpd/w_encounter2_camp.map-3-dfs-opt.txt
# ../outputs/cpd/orz303d.map-3-dfs-opt-inv.txt
# ../outputs/cpd/orz999d.map-3-dfs-c8.txt
# ../outputs/cpd/random-100-33.map-3-dfs-opt-inv.txt
# ../outputs/cpd/Aurora.map-3-dfs-c64.txt
# ../outputs/cpd/lt_0_lowtown_n.map-3-dfs-opt-inv.txt
# ../outputs/cpd/orz704d.map-3-dfs-c8.txt
# ../outputs/cpd/room-100-10.map-3-dfs-opt.txt
# ../outputs/cpd/lt_gallowstemplar.map-3-dfs-c32.txt
# ../outputs/cpd/room-100-10.map-3-dfs-c16.txt
# ../outputs/cpd/lt_warehouse_n.map-3-dfs-c4.txt
# ../outputs/cpd/lt_foundry_n.map-3-dfs-c4-inv.txt
# ../outputs/cpd/Brushfire.map-3-dfs-c64-inv.txt
# ../outputs/cpd/BrokenSteppes.map-3-dfs-c8-inv.txt
# ../outputs/cpd/dr_slavers.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz303d.map-3-dfs-c8.txt
# ../outputs/cpd/orz500d.map-3-dfs-c32-inv.txt
# ../outputs/cpd/random-100-33.map-3-dfs-c4.txt
# ../outputs/cpd/lt_gamlenshouse_n.map-3-dfs-c32.txt
# ../outputs/cpd/w_bonepit.map-3-dfs-opt-inv.txt
# ../outputs/cpd/orz302d.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_foundry_n.map-3-dfs-c4.txt
# ../outputs/cpd/dr_dungeon.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz100d.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_0_lowtown_a3_n_c.map-3-dfs-c64.txt
# ../outputs/cpd/ht_0_hightown_a3.map-3-dfs-c32.txt
# ../outputs/cpd/lt_0_lowtown_n.map-3-dfs-c2.txt
# ../outputs/cpd/lt_undercitydungeon.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks_a3.map-3-dfs-c32.txt
# ../outputs/cpd/lt_0_lowtown_docks_a3.map-3-dfs-c4.txt
# ../outputs/cpd/orz701d.map-3-dfs-c64.txt
# ../outputs/cpd/lt_ruinedhouse_n.map-3-dfs-c16-inv.txt
# ../outputs/cpd/orz107d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/Brushfire.map-3-dfs-c32-inv.txt
# ../outputs/cpd/ArcticStation.map-3-dfs-c64.txt
# ../outputs/cpd/ht_0_hightown_a2.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_warehouse.map-3-dfs-c2.txt
# ../outputs/cpd/lt_backalley_n.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_0_lowtown_a3_n_c.map-3-dfs-c2.txt
# ../outputs/cpd/orz106d.map-3-dfs-c8.txt
# ../outputs/cpd/ht_mansion2b.map-3-dfs-c2-inv.txt
# ../outputs/cpd/ca_caverns1.map-3-dfs-c8-inv.txt
# ../outputs/cpd/BigGameHunters.map-3-dfs-c4.txt
# ../outputs/cpd/lt_hangedman.map-3-dfs-c2-inv.txt
# ../outputs/cpd/w_encounter3.map-3-dfs-c4-inv.txt
# ../outputs/cpd/Aurora.map-3-dfs-c4-inv.txt
# ../outputs/cpd/w_encounter1.map-3-dfs-c2-inv.txt
# ../outputs/cpd/orz107d.map-3-dfs-c32.txt
# ../outputs/cpd/lt_ruinedhouse_n.map-3-dfs-c64-inv.txt
# ../outputs/cpd/w_bonepitmining_a2.map-3-dfs-c64.txt
# ../outputs/cpd/lt_undercitydungeon.map-3-dfs-opt.txt
# ../outputs/cpd/orz800d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/lt_undercitydungeon.map-3-dfs-c16.txt
# ../outputs/cpd/maze-400-4.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_undercitydungeon.map-3-dfs-c64-inv.txt
# ../outputs/cpd/lt_gamlenshouse_n.map-3-dfs-opt-inv.txt
# ../outputs/cpd/dr_dungeon.map-3-dfs-c16-inv.txt
# ../outputs/cpd/room-100-10.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_foundry_n.map-3-dfs-c16.txt
# ../outputs/cpd/Archipelago.map-3-dfs-c2-inv.txt
# ../outputs/cpd/lt_foundry_n.map-3-dfs-opt.txt
# ../outputs/cpd/dr_0_deeproads.map-3-dfs-c8-inv.txt
# ../outputs/cpd/lt_ruinedhouse_n.map-3-dfs-c8-inv.txt
# ../outputs/cpd/lt_gallowscourtyard_n.map-3-dfs-c4.txt
# ../outputs/cpd/lt_backalley_g.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz999d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/ArcticStation.map-3-dfs-c8.txt
# ../outputs/cpd/Backwoods.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz302d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/lt_0_lowtown_a3_n_c.map-3-dfs-c8-inv.txt
# ../outputs/cpd/random-100-33.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz702d.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_0_lowtown.map-3-dfs-c4-inv.txt
# ../outputs/cpd/ht_0_hightown.map-3-dfs-c2.txt
# ../outputs/cpd/orz800d.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz101d.map-3-dfs-c64-inv.txt
# ../outputs/cpd/ca_cave.map-3-dfs-c64.txt
# ../outputs/cpd/orz100d.map-3-dfs-c32-inv.txt
# ../outputs/cpd/lt_0_lowtown_a2_n.map-3-dfs-c64.txt
# ../outputs/cpd/orz201d.map-3-dfs-c64.txt
# ../outputs/cpd/dr_slavers.map-3-dfs-c32-inv.txt
# ../outputs/cpd/w_blightlands.map-3-dfs-opt.txt
# ../outputs/cpd/lt_gallowscourtyard.map-3-dfs-c4.txt
# ../outputs/cpd/lt_darktown.map-3-dfs-opt-inv.txt
# ../outputs/cpd/w_blightlands.map-3-dfs-c16.txt
# ../outputs/cpd/lt_backalley_n.map-3-dfs-c4.txt
# ../outputs/cpd/lt_shop.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ca_cave.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz700d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/ca_caverns2.map-3-dfs-c4.txt
# ../outputs/cpd/orz203d.map-3-dfs-c8.txt
# ../outputs/cpd/orz201d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/ht_mansion2.map-3-dfs-c32-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks_a3.map-3-dfs-c2-inv.txt
# ../outputs/cpd/ht_mansion_n.map-3-dfs-c64-inv.txt
# ../outputs/cpd/ht_0_hightown.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ht_0_hightown.map-3-dfs-c4-inv.txt
# ../outputs/cpd/dr_primevaltomb.map-3-dfs-c32.txt
# ../outputs/cpd/ca_caverns2prc.map-3-dfs-c2.txt
# ../outputs/cpd/ht_mansion_n.map-3-dfs-c16-inv.txt
# ../outputs/cpd/orz901d.map-3-dfs-c8.txt
# ../outputs/cpd/orz702d.map-3-dfs-c8.txt
# ../outputs/cpd/w_encounter1.map-3-dfs-opt-inv.txt
# ../outputs/cpd/w_encounter2_camp.map-3-dfs-c64.txt
# ../outputs/cpd/Aftershock.map-3-dfs-c4-inv.txt
# ../outputs/cpd/ht_brothel_n.map-3-dfs-c64.txt
# ../outputs/cpd/lt_0_lowtown_n.map-3-dfs-c2-inv.txt
# ../outputs/cpd/orz303d.map-3-dfs-c32.txt
# ../outputs/cpd/orz101d.map-3-dfs-c16-inv.txt
# ../outputs/cpd/Aurora.map-3-dfs-c16.txt
# ../outputs/cpd/orz800d.map-3-dfs-c16-inv.txt
# ../outputs/cpd/Aurora.map-3-dfs-opt.txt
# ../outputs/cpd/lt_hangedman.map-3-dfs-opt-inv.txt
# ../outputs/cpd/w_bonepit.map-3-dfs-c8.txt
# ../outputs/cpd/AcrosstheCape.map-3-dfs-c8-inv.txt
# ../outputs/cpd/room-100-10.map-3-dfs-c64.txt
# ../outputs/cpd/lt_0_lowtown.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_ruinedhouse_n.map-3-dfs-c2.txt
# ../outputs/cpd/lt_0_lowtown_docks.map-3-dfs-c4-inv.txt
# ../outputs/cpd/room-400-40.map-3-dfs-c8.txt
# ../outputs/cpd/ht_keep.map-3-dfs-c16.txt
# ../outputs/cpd/w_woundedcoast.map-3-dfs-c32.txt
# ../outputs/cpd/ca_caverns2.map-3-dfs-c4-inv.txt
# ../outputs/cpd/dr_primevalentrance.map-3-dfs-c2-inv.txt
# ../outputs/cpd/ht_keep.map-3-dfs-opt.txt
# ../outputs/cpd/AcrosstheCape.map-3-dfs-c32.txt
# ../outputs/cpd/orz000d.map-3-dfs-c2-inv.txt
# ../outputs/cpd/w_bonepit.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz304d.map-3-dfs-c64.txt
# ../outputs/cpd/lt_shop.map-3-dfs-c16.txt
# ../outputs/cpd/lt_shop.map-3-dfs-opt.txt
# ../outputs/cpd/orz103d.map-3-dfs-c2-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks_a3_n.map-3-dfs-c16.txt
# ../outputs/cpd/lt_0_lowtown_docks_a3_n.map-3-dfs-opt.txt
# ../outputs/cpd/BlastFurnace.map-3-dfs-c2.txt
# ../outputs/cpd/w_bonepitdestroyed_a3.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz203d.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_hangedman_n.map-3-dfs-c4.txt
# ../outputs/cpd/orz302d.map-3-dfs-opt.txt
# ../outputs/cpd/orz302d.map-3-dfs-c16.txt
# ../outputs/cpd/random-400-33.map-3-dfs-c32-inv.txt
# ../outputs/cpd/lt_0_lowtown_a2_n_c.map-3-dfs-c32.txt
# ../outputs/cpd/lt_hangedman_n.map-3-dfs-c16.txt
# ../outputs/cpd/room-100-10.map-3-dfs-c2.txt
# ../outputs/cpd/lt_hangedman_n.map-3-dfs-opt.txt
# ../outputs/cpd/ht_mansion_n.map-3-dfs-c32.txt
# ../outputs/cpd/BlastFurnace.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_gallowstemplar.map-3-dfs-c32-inv.txt
# ../outputs/cpd/lt_gallowsprison_n.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz103d.map-3-dfs-c8.txt
# ../outputs/cpd/BrokenSteppes.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ht_mansion_n.map-3-dfs-c2.txt
# ../outputs/cpd/lt_gallowscourtyard.map-3-dfs-c64.txt
# ../outputs/cpd/ht_0_hightown_n.map-3-dfs-c2-inv.txt
# ../outputs/cpd/ht_0_hightown_a2.map-3-dfs-c4.txt
# ../outputs/cpd/w_encounter3.map-3-dfs-c4.txt
# ../outputs/cpd/orz100d.map-3-dfs-c64.txt
# ../outputs/cpd/orz106d.map-3-dfs-c64-inv.txt
# ../outputs/cpd/ht_brothel_n.map-3-dfs-c4.txt
# ../outputs/cpd/orz107d.map-3-dfs-c32-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks.map-3-dfs-c16-inv.txt
# ../outputs/cpd/orz901d.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz900d.map-3-dfs-c32-inv.txt
# ../outputs/cpd/lt_0_lowtown_a2.map-3-dfs-c2-inv.txt
# ../outputs/cpd/orz000d.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz704d.map-3-dfs-c2-inv.txt
# ../outputs/cpd/w_encounter2.map-3-dfs-c32.txt
# ../outputs/cpd/lt_backalley_n.map-3-dfs-c64-inv.txt
# ../outputs/cpd/dr_primevaltomb.map-3-dfs-c32-inv.txt
# ../outputs/cpd/ht_brothel_n.map-3-dfs-c32-inv.txt
# ../outputs/cpd/ht_playershouse_n.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ArcticStation.map-3-dfs-opt-inv.txt
# ../outputs/cpd/room-400-40.map-3-dfs-c64.txt
# ../outputs/cpd/ht_store.map-3-dfs-c2.txt
# ../outputs/cpd/lt_gallowscourtyard_n.map-3-dfs-c2-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks_n.map-3-dfs-c2.txt
# ../outputs/cpd/Archipelago.map-3-dfs-opt.txt
# ../outputs/cpd/orz106d.map-3-dfs-opt.txt
# ../outputs/cpd/lt_hangedman_n.map-3-dfs-c2-inv.txt
# ../outputs/cpd/Archipelago.map-3-dfs-c16.txt
# ../outputs/cpd/orz106d.map-3-dfs-c16.txt
# ../outputs/cpd/maze-400-4.map-3-dfs-c32-inv.txt
# ../outputs/cpd/lt_backalley_n.map-3-dfs-c16-inv.txt
# ../outputs/cpd/ht_0_hightown_n.map-3-dfs-c32.txt
# ../outputs/cpd/ht_chantry_n.map-3-dfs-c64.txt
# ../outputs/cpd/BlackLotus.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz000d.map-3-dfs-c16-inv.txt
# ../outputs/cpd/orz901d.map-3-dfs-c16-inv.txt
# ../outputs/cpd/ht_playershouse_n.map-3-dfs-c8-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks.map-3-dfs-c64-inv.txt
# ../outputs/cpd/lt_undercityencounter.map-3-dfs-c4.txt
# ../outputs/cpd/orz106d.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_gamlenshouse_n.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks.map-3-dfs-opt.txt
# ../outputs/cpd/ca_cavern1_haunted.map-3-dfs-c32.txt
# ../outputs/cpd/lt_gallowstemplar_f.map-3-dfs-c16.txt
# ../outputs/cpd/lt_0_lowtown_docks.map-3-dfs-c16.txt
# ../outputs/cpd/lt_gallowstemplar_f.map-3-dfs-opt.txt
# ../outputs/cpd/w_blightlands.map-3-dfs-c2-inv.txt
# ../outputs/cpd/w_bonepitdestroyed_a3.map-3-dfs-c32.txt
# ../outputs/cpd/orz601d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz900d.map-3-dfs-c32.txt
# ../outputs/cpd/orz302d.map-3-dfs-c8.txt
# ../outputs/cpd/random-100-33.map-3-dfs-c2.txt
# ../outputs/cpd/Brushfire.map-3-dfs-c32.txt
# ../outputs/cpd/lt_hangedman_n.map-3-dfs-c16-inv.txt
# ../outputs/cpd/BigGameHunters.map-3-dfs-c16-inv.txt
# ../outputs/cpd/ht_0_hightown_a2.map-3-dfs-c32.txt
# ../outputs/cpd/lt_0_lowtown_n.map-3-dfs-c4.txt
# ../outputs/cpd/ht_store.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz300d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/maze-400-4.map-3-dfs-c64.txt
# ../outputs/cpd/lt_foundry_n.map-3-dfs-c2.txt
# ../outputs/cpd/BrokenSteppes.map-3-dfs-c8.txt
# ../outputs/cpd/orz203d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/dr_slavers.map-3-dfs-c64.txt
# ../outputs/cpd/lt_0_lowtown_docks_a3.map-3-dfs-c2.txt
# ../outputs/cpd/ht_keep_n.map-3-dfs-c8-inv.txt
# ../outputs/cpd/ht_keep.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz702d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/lt_warehouse.map-3-dfs-c4.txt
# ../outputs/cpd/lt_0_lowtown_a2_n.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz103d.map-3-dfs-c64.txt
# ../outputs/cpd/dr_0_deeproads.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ht_chantry_n.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz999d.map-3-dfs-opt.txt
# ../outputs/cpd/BigGameHunters.map-3-dfs-c2.txt
# ../outputs/cpd/lt_0_lowtown_a2.map-3-dfs-c32.txt
# ../outputs/cpd/lt_0_lowtown_a2_n_c.map-3-dfs-c2-inv.txt
# ../outputs/cpd/orz999d.map-3-dfs-c16.txt
# ../outputs/cpd/lt_0_lowtown_a2_n.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_gallowstemplar_n.map-3-dfs-c4-inv.txt
# ../outputs/cpd/w_sundermount.map-3-dfs-c64.txt
# ../outputs/cpd/lt_0_lowtown_n.map-3-dfs-opt.txt
# ../outputs/cpd/w_encounter3.map-3-dfs-opt-inv.txt
# ../outputs/cpd/orz107d.map-3-dfs-c8.txt
# ../outputs/cpd/lt_0_lowtown_n.map-3-dfs-c16.txt
# ../outputs/cpd/ht_brothel_n.map-3-dfs-c2-inv.txt
# ../outputs/cpd/lt_0_lowtown_a3_n_c.map-3-dfs-c4.txt
# ../outputs/cpd/lt_gallowscourtyard_n.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz200d.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ht_0_hightown.map-3-dfs-c64.txt
# ../outputs/cpd/orz601d.map-3-dfs-opt.txt
# ../outputs/cpd/ht_0_hightown_a2.map-3-dfs-c32-inv.txt
# ../outputs/cpd/lt_warehouse.map-3-dfs-c2-inv.txt
# ../outputs/cpd/Backwoods.map-3-dfs-c8.txt
# ../outputs/cpd/orz601d.map-3-dfs-c16.txt
# ../outputs/cpd/random-400-33.map-3-dfs-c32.txt
# ../outputs/cpd/w_sundermount.map-3-dfs-c4-inv.txt
# ../outputs/cpd/orz105d.map-3-dfs-c16.txt
# ../outputs/cpd/BigGameHunters.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz105d.map-3-dfs-opt.txt
# ../outputs/cpd/w_sundermount.map-3-dfs-c32-inv.txt
# ../outputs/cpd/lt_gallowscourtyard_n.map-3-dfs-c2.txt
# ../outputs/cpd/lt_hangedman_n.map-3-dfs-c64-inv.txt
# ../outputs/cpd/w_bonepitdestroyed_a3.map-3-dfs-c8.txt
# ../outputs/cpd/lt_gallowstemplar_f.map-3-dfs-c32-inv.txt
# ../outputs/cpd/Aftershock.map-3-dfs-c64.txt
# ../outputs/cpd/orz800d.map-3-dfs-c8.txt
# ../outputs/cpd/dr_dungeon.map-3-dfs-c16.txt
# ../outputs/cpd/dr_primevaltomb.map-3-dfs-c8-inv.txt
# ../outputs/cpd/ca_caverns1.map-3-dfs-c32.txt
# ../outputs/cpd/dr_dungeon.map-3-dfs-opt.txt
# ../outputs/cpd/dr_primevalentrance.map-3-dfs-opt-inv.txt
# ../outputs/cpd/orz105d.map-3-dfs-c16-inv.txt
# ../outputs/cpd/orz102d.map-3-dfs-c4-inv.txt
# ../outputs/cpd/room-400-40.map-3-dfs-c2-inv.txt
# ../outputs/cpd/maze-100-1.map-3-dfs-c8.txt
# ../outputs/cpd/ca_caverns1.map-3-dfs-c16-inv.txt
# ../outputs/cpd/ht_mansion2.map-3-dfs-c2-inv.txt
# ../outputs/cpd/ht_0_hightown.map-3-dfs-c4.txt
# ../outputs/cpd/ca_cavern1_haunted.map-3-dfs-c16-inv.txt
# ../outputs/cpd/ht_keep.map-3-dfs-c4-inv.txt
# ../outputs/cpd/ca_caverns1.map-3-dfs-c8.txt
# ../outputs/cpd/BlastFurnace.map-3-dfs-c32-inv.txt
# ../outputs/cpd/ca_caverns2.map-3-dfs-c2.txt
# ../outputs/cpd/orz500d.map-3-dfs-c4-inv.txt
# ../outputs/cpd/ht_0_hightown_n.map-3-dfs-c64-inv.txt
# ../outputs/cpd/lt_backalley_n.map-3-dfs-c2.txt
# ../outputs/cpd/lt_gallowscourtyard.map-3-dfs-c2.txt
# ../outputs/cpd/dr_primevalentrance.map-3-dfs-c8.txt
# ../outputs/cpd/lt_house.map-3-dfs-opt.txt
# ../outputs/cpd/lt_house.map-3-dfs-c16.txt
# ../outputs/cpd/lt_0_lowtown_a3_n_c.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz105d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/lt_warehouse_n.map-3-dfs-c32.txt
# ../outputs/cpd/orz900d.map-3-dfs-c8.txt
# ../outputs/cpd/ca_caverns2prc.map-3-dfs-c4.txt
# ../outputs/cpd/ht_keep_n.map-3-dfs-c32-inv.txt
# ../outputs/cpd/ht_0_hightown_n.map-3-dfs-c16-inv.txt
# ../outputs/cpd/ht_store.map-3-dfs-c4-inv.txt
# ../outputs/cpd/ht_chantry_n.map-3-dfs-opt-inv.txt
# ../outputs/cpd/orz703d.map-3-dfs-c8.txt
# ../outputs/cpd/orz301d.map-3-dfs-c16.txt
# ../outputs/cpd/ca_cavern1_haunted.map-3-dfs-c64-inv.txt
# ../outputs/cpd/Backwoods.map-3-dfs-c64.txt
# ../outputs/cpd/orz301d.map-3-dfs-opt.txt
# ../outputs/cpd/ca_caverns1.map-3-dfs-c64-inv.txt
# ../outputs/cpd/w_encounter2.map-3-dfs-c32-inv.txt
# ../outputs/cpd/lt_undercityencounter.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_0_lowtown_a2.map-3-dfs-c8.txt
# ../outputs/cpd/lt_ruinedhouse_n.map-3-dfs-c32.txt
# ../outputs/cpd/lt_0_lowtown_docks_a3_n.map-3-dfs-c8.txt
# ../outputs/cpd/orz105d.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz901d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/lt_ruinedhouse_n.map-3-dfs-c4.txt
# ../outputs/cpd/lt_warehouse_n.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks_n.map-3-dfs-c8-inv.txt
# ../outputs/cpd/ht_0_hightown_a3.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_undercitydungeon.map-3-dfs-c8-inv.txt
# ../outputs/cpd/lt_gallowstemplar_n.map-3-dfs-c32-inv.txt
# ../outputs/cpd/lt_undercityencounter.map-3-dfs-c32.txt
# ../outputs/cpd/AcrosstheCape.map-3-dfs-c8.txt
# ../outputs/cpd/lt_darktown.map-3-dfs-c32.txt
# ../outputs/cpd/lt_0_lowtown_docks_a3.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz304d.map-3-dfs-c2-inv.txt
# ../outputs/cpd/ca_cave.map-3-dfs-c8.txt
# ../outputs/cpd/ht_mansion_n.map-3-dfs-c8-inv.txt
# ../outputs/cpd/lt_undercityencounter.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_gallowstemplar_f.map-3-dfs-c2-inv.txt
# ../outputs/cpd/lt_house.map-3-dfs-c64-inv.txt
# ../outputs/cpd/lt_gallowsprison_n.map-3-dfs-c64-inv.txt
# ../outputs/cpd/lt_warehouse.map-3-dfs-opt-inv.txt
# ../outputs/cpd/BlastFurnace.map-3-dfs-c4.txt
# ../outputs/cpd/ht_bartrand_n.map-3-dfs-c64.txt
# ../outputs/cpd/lt_gallowsprison_n.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_house.map-3-dfs-c16-inv.txt
# ../outputs/cpd/ht_chantry.map-3-dfs-c8-inv.txt
# ../outputs/cpd/lt_hangedman_n.map-3-dfs-c2.txt
# ../outputs/cpd/orz500d.map-3-dfs-c16.txt
# ../outputs/cpd/lt_0_lowtown_a2_n.map-3-dfs-c2-inv.txt
# ../outputs/cpd/orz500d.map-3-dfs-opt.txt
# ../outputs/cpd/room-100-10.map-3-dfs-c4.txt
# ../outputs/cpd/lt_warehouse_n.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks_a3_n.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz301d.map-3-dfs-opt-inv.txt
# ../outputs/cpd/random-400-33.map-3-dfs-c2-inv.txt
# ../outputs/cpd/orz102d.map-3-dfs-c8.txt
# ../outputs/cpd/lt_0_lowtown_a2_n.map-3-dfs-c8.txt
# ../outputs/cpd/lt_0_lowtown_docks_a3.map-3-dfs-c16-inv.txt
# ../outputs/cpd/orz300d.map-3-dfs-c32.txt
# ../outputs/cpd/ht_0_hightown_a2.map-3-dfs-c2.txt
# ../outputs/cpd/random-400-33.map-3-dfs-c8.txt
# ../outputs/cpd/room-400-40.map-3-dfs-c32-inv.txt
# ../outputs/cpd/ca_cavern1_haunted.map-3-dfs-c2-inv.txt
# ../outputs/cpd/ht_mansion_n.map-3-dfs-c4.txt
# ../outputs/cpd/AcrosstheCape.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ca_caverns2prc.map-3-dfs-c64-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks_n.map-3-dfs-opt-inv.txt
# ../outputs/cpd/w_encounter3.map-3-dfs-c2.txt
# ../outputs/cpd/dr_dungeon.map-3-dfs-c2-inv.txt
# ../outputs/cpd/orz102d.map-3-dfs-c16-inv.txt
# ../outputs/cpd/orz702d.map-3-dfs-c64.txt
# ../outputs/cpd/ca_cave.map-3-dfs-c16-inv.txt
# ../outputs/cpd/ht_brothel_n.map-3-dfs-c2.txt
# ../outputs/cpd/orz901d.map-3-dfs-c16.txt
# ../outputs/cpd/lt_backalley_g.map-3-dfs-opt.txt
# ../outputs/cpd/orz901d.map-3-dfs-opt.txt
# ../outputs/cpd/lt_backalley_g.map-3-dfs-c16.txt
# ../outputs/cpd/maze-100-1.map-3-dfs-opt-inv.txt
# ../outputs/cpd/dr_dungeon.map-3-dfs-c8.txt
# ../outputs/cpd/BlackLotus.map-3-dfs-c8.txt
# ../outputs/cpd/w_encounter3.map-3-dfs-c32.txt
# ../outputs/cpd/ht_chantry.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_gallowstemplar_n.map-3-dfs-c32.txt
# ../outputs/cpd/ht_store.map-3-dfs-c4.txt
# ../outputs/cpd/lt_0_lowtown_docks_n.map-3-dfs-c4.txt
# ../outputs/cpd/orz101d.map-3-dfs-c2-inv.txt
# ../outputs/cpd/lt_backalley_n.map-3-dfs-c32.txt
# ../outputs/cpd/ca_caverns2prc.map-3-dfs-c64.txt
# ../outputs/cpd/lt_gallowscourtyard.map-3-dfs-c4-inv.txt
# ../outputs/cpd/ht_chantry.map-3-dfs-c64.txt
# ../outputs/cpd/room-100-10.map-3-dfs-c4-inv.txt
# ../outputs/cpd/orz704d.map-3-dfs-c16.txt
# ../outputs/cpd/ht_chantry.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz704d.map-3-dfs-opt.txt
# ../outputs/cpd/ht_mansion2.map-3-dfs-c64.txt
# ../outputs/cpd/lt_0_lowtown.map-3-dfs-c8.txt
# ../outputs/cpd/Brushfire.map-3-dfs-c2-inv.txt
# ../outputs/cpd/lt_gallowscourtyard_n.map-3-dfs-c32.txt
# ../outputs/cpd/orz000d.map-3-dfs-opt.txt
# ../outputs/cpd/orz000d.map-3-dfs-c16.txt
# ../outputs/cpd/lt_undercityencounter.map-3-dfs-c2.txt
# ../outputs/cpd/BigGameHunters.map-3-dfs-c64.txt
# ../outputs/cpd/lt_0_lowtown_docks_a3_n.map-3-dfs-opt-inv.txt
# ../outputs/cpd/orz102d.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz103d.map-3-dfs-c32-inv.txt
# ../outputs/cpd/ca_cave.map-3-dfs-c64-inv.txt
# ../outputs/cpd/lt_0_lowtown.map-3-dfs-opt.txt
# ../outputs/cpd/ca_caverns2prc.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_0_lowtown.map-3-dfs-c16.txt
# ../outputs/cpd/BlastFurnace.map-3-dfs-c16.txt
# ../outputs/cpd/orz701d.map-3-dfs-opt-inv.txt
# ../outputs/cpd/w_bonepitdestroyed_a3.map-3-dfs-c4-inv.txt
# ../outputs/cpd/BlastFurnace.map-3-dfs-opt.txt
# ../outputs/cpd/lt_undercityencounter.map-3-dfs-c16.txt
# ../outputs/cpd/lt_darktown.map-3-dfs-opt.txt
# ../outputs/cpd/dr_0_deeproads.map-3-dfs-c64-inv.txt
# ../outputs/cpd/lt_0_lowtown_a2_n.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_darktown.map-3-dfs-c16.txt
# ../outputs/cpd/lt_undercityencounter.map-3-dfs-opt.txt
# ../outputs/cpd/lt_gallowscourtyard.map-3-dfs-c32-inv.txt
# ../outputs/cpd/ht_store.map-3-dfs-c8-inv.txt
# ../outputs/cpd/w_encounter3.map-3-dfs-c16-inv.txt
# ../outputs/cpd/room-400-40.map-3-dfs-c2.txt
# ../outputs/cpd/AcrosstheCape.map-3-dfs-c4.txt
# ../outputs/cpd/ca_cave.map-3-dfs-c4.txt
# ../outputs/cpd/orz200d.map-3-dfs-c16-inv.txt
# ../outputs/cpd/ArcticStation.map-3-dfs-c2-inv.txt
# ../outputs/cpd/lt_house.map-3-dfs-c2-inv.txt
# ../outputs/cpd/orz901d.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks_n.map-3-dfs-c4-inv.txt
# ../outputs/cpd/Aftershock.map-3-dfs-c32-inv.txt
# ../outputs/cpd/lt_undercityencounter.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz999d.map-3-dfs-c32-inv.txt
# ../outputs/cpd/BlastFurnace.map-3-dfs-c8.txt
# ../outputs/cpd/maze-100-1.map-3-dfs-c2-inv.txt
# ../outputs/cpd/lt_hangedman_n.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ht_keep.map-3-dfs-c8-inv.txt
# ../outputs/cpd/room-100-10.map-3-dfs-c8.txt
# ../outputs/cpd/BigGameHunters.map-3-dfs-opt-inv.txt
# ../outputs/cpd/orz500d.map-3-dfs-c32.txt
# ../outputs/cpd/orz102d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz103d.map-3-dfs-c2.txt
# ../outputs/cpd/orz102d.map-3-dfs-c4.txt
# ../outputs/cpd/lt_shop.map-3-dfs-c2-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks_n.map-3-dfs-c64.txt
# ../outputs/cpd/ca_caverns2.map-3-dfs-c64.txt
# ../outputs/cpd/lt_0_lowtown_a2_n.map-3-dfs-c4.txt
# ../outputs/cpd/lt_undercityserialkiller.map-3-dfs-c2-inv.txt
# ../outputs/cpd/orz201d.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz200d.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz105d.map-3-dfs-c4-inv.txt
# ../outputs/cpd/w_encounter3.map-3-dfs-c64-inv.txt
# ../outputs/cpd/ht_mansion_n.map-3-dfs-c8.txt
# ../outputs/cpd/orz300d.map-3-dfs-c16.txt
# ../outputs/cpd/orz500d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz300d.map-3-dfs-opt.txt
# ../outputs/cpd/ca_caverns1_mines.map-3-dfs-c32-inv.txt
# ../outputs/cpd/dr_0_deeproads.map-3-dfs-c16-inv.txt
# ../outputs/cpd/random-400-33.map-3-dfs-c4.txt
# ../outputs/cpd/ht_mansion2b.map-3-dfs-c32-inv.txt
# ../outputs/cpd/ht_chantry_n.map-3-dfs-c4-inv.txt
# ../outputs/cpd/orz901d.map-3-dfs-c32.txt
# ../outputs/cpd/ht_0_hightown_n.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_backalley_g.map-3-dfs-c32.txt
# ../outputs/cpd/lt_gallowstemplar_n.map-3-dfs-c8-inv.txt
# ../outputs/cpd/w_encounter2_camp.map-3-dfs-c2-inv.txt
# ../outputs/cpd/ht_chantry_n.map-3-dfs-c16-inv.txt
# ../outputs/cpd/BlackLotus.map-3-dfs-c4.txt
# ../outputs/cpd/dr_dungeon.map-3-dfs-c4.txt
# ../outputs/cpd/orz102d.map-3-dfs-c64.txt
# ../outputs/cpd/lt_gallowstemplar_n.map-3-dfs-c16.txt
# ../outputs/cpd/dr_primevaltomb.map-3-dfs-c4-inv.txt
# ../outputs/cpd/w_encounter3.map-3-dfs-c16.txt
# ../outputs/cpd/lt_gallowstemplar_n.map-3-dfs-opt.txt
# ../outputs/cpd/w_encounter3.map-3-dfs-opt.txt
# ../outputs/cpd/ht_store.map-3-dfs-c8.txt
# ../outputs/cpd/lt_0_lowtown_docks_n.map-3-dfs-c8.txt
# ../outputs/cpd/dr_primevalentrance.map-3-dfs-c64.txt
# ../outputs/cpd/lt_warehouse_n.map-3-dfs-c16-inv.txt
# ../outputs/cpd/w_sundermount.map-3-dfs-c8-inv.txt
# ../outputs/cpd/ht_0_hightown_a3.map-3-dfs-c16-inv.txt
# ../outputs/cpd/dr_primevalentrance.map-3-dfs-c64-inv.txt
# ../outputs/cpd/ht_0_hightown_a3.map-3-dfs-c64-inv.txt
# ../outputs/cpd/dr_primevalentrance.map-3-dfs-c16-inv.txt
# ../outputs/cpd/orz300d.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_backalley_n.map-3-dfs-c16.txt
# ../outputs/cpd/lt_warehouse_n.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz105d.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_backalley_n.map-3-dfs-opt.txt
# ../outputs/cpd/orz601d.map-3-dfs-c4-inv.txt
# ../outputs/cpd/orz704d.map-3-dfs-c32.txt
# ../outputs/cpd/ca_caverns1.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ca_cavern1_haunted.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ht_keep_n.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_gallowscourtyard_n.map-3-dfs-c16.txt
# ../outputs/cpd/ht_chantry_n.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz702d.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_0_lowtown.map-3-dfs-c4.txt
# ../outputs/cpd/orz000d.map-3-dfs-c32.txt
# ../outputs/cpd/lt_gallowscourtyard_n.map-3-dfs-opt.txt
# ../outputs/cpd/BlastFurnace.map-3-dfs-c32.txt
# ../outputs/cpd/orz601d.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz203d.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_0_lowtown.map-3-dfs-c32.txt
# ../outputs/cpd/dr_0_deeproads.map-3-dfs-c64.txt
# ../outputs/cpd/orz900d.map-3-dfs-c16.txt
# ../outputs/cpd/room-100-10.map-3-dfs-c8-inv.txt
# ../outputs/cpd/Brushfire.map-3-dfs-opt.txt
# ../outputs/cpd/lt_gallowsprison_n.map-3-dfs-opt-inv.txt
# ../outputs/cpd/orz900d.map-3-dfs-opt.txt
# ../outputs/cpd/lt_warehouse.map-3-dfs-c64-inv.txt
# ../outputs/cpd/Brushfire.map-3-dfs-c16.txt
# ../outputs/cpd/lt_house.map-3-dfs-opt-inv.txt
# ../outputs/cpd/orz303d.map-3-dfs-c2.txt
# ../outputs/cpd/orz302d.map-3-dfs-c4.txt
# ../outputs/cpd/ht_keep_n.map-3-dfs-c64.txt
# ../outputs/cpd/orz703d.map-3-dfs-c64.txt
# ../outputs/cpd/lt_0_lowtown_n.map-3-dfs-c8.txt
# ../outputs/cpd/BrokenSteppes.map-3-dfs-c4.txt
# ../outputs/cpd/ht_0_hightown_a2.map-3-dfs-c16.txt
# ../outputs/cpd/lt_foundry_n.map-3-dfs-c2-inv.txt
# ../outputs/cpd/lt_undercityencounter.map-3-dfs-c64-inv.txt
# ../outputs/cpd/ht_0_hightown_a2.map-3-dfs-opt.txt
# ../outputs/cpd/lt_gallowscourtyard.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz301d.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_0_lowtown_a2_n_c.map-3-dfs-c32-inv.txt
# ../outputs/cpd/w_bonepitdestroyed_a3.map-3-dfs-c8-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks_a3.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_warehouse.map-3-dfs-c8.txt
# ../outputs/cpd/lt_0_lowtown_n.map-3-dfs-c32.txt
# ../outputs/cpd/lt_0_lowtown_a2.map-3-dfs-c16.txt
# ../outputs/cpd/lt_0_lowtown_a3_n_c.map-3-dfs-c8.txt
# ../outputs/cpd/lt_0_lowtown_a2.map-3-dfs-opt.txt
# ../outputs/cpd/orz999d.map-3-dfs-c32.txt
# ../outputs/cpd/orz106d.map-3-dfs-c2.txt
# ../outputs/cpd/orz107d.map-3-dfs-c4.txt
# ../outputs/cpd/orz601d.map-3-dfs-c32.txt
# ../outputs/cpd/orz301d.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz300d.map-3-dfs-c32-inv.txt
# ../outputs/cpd/Backwoods.map-3-dfs-c4.txt
# ../outputs/cpd/orz106d.map-3-dfs-c2-inv.txt
# ../outputs/cpd/orz105d.map-3-dfs-c32.txt
# ../outputs/cpd/random-400-33.map-3-dfs-c16.txt
# ../outputs/cpd/lt_undercityencounter.map-3-dfs-c16-inv.txt
# ../outputs/cpd/ca_caverns1_mines.map-3-dfs-c64.txt
# ../outputs/cpd/random-400-33.map-3-dfs-opt.txt
# ../outputs/cpd/lt_undercityserialkiller.map-3-dfs-c32-inv.txt
# ../outputs/cpd/dr_dungeon.map-3-dfs-c32.txt
# ../outputs/cpd/ca_caverns1.map-3-dfs-opt.txt
# ../outputs/cpd/w_bonepitdestroyed_a3.map-3-dfs-c4.txt
# ../outputs/cpd/ca_caverns1.map-3-dfs-c16.txt
# ../outputs/cpd/lt_warehouse.map-3-dfs-c16-inv.txt
# ../outputs/cpd/orz800d.map-3-dfs-c4.txt
# ../outputs/cpd/ArcticStation.map-3-dfs-c2.txt
# ../outputs/cpd/maze-100-1.map-3-dfs-c4.txt
# ../outputs/cpd/lt_warehouse_n.map-3-dfs-c8-inv.txt
# ../outputs/cpd/BigGameHunters.map-3-dfs-c2-inv.txt
# ../outputs/cpd/ca_caverns1.map-3-dfs-c4.txt
# ../outputs/cpd/ht_bartrand_n.map-3-dfs-c32-inv.txt
# ../outputs/cpd/ht_0_hightown.map-3-dfs-c8.txt
# ../outputs/cpd/ht_chantry.map-3-dfs-c4-inv.txt
# ../outputs/cpd/maze-100-1.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz203d.map-3-dfs-c64.txt
# ../outputs/cpd/lt_0_lowtown_docks_a3_n.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks_n.map-3-dfs-c64-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks_a3_n.map-3-dfs-c4-inv.txt
# ../outputs/cpd/dr_primevalentrance.map-3-dfs-c4.txt
# ../outputs/cpd/lt_house.map-3-dfs-c32.txt
# ../outputs/cpd/ca_caverns2prc.map-3-dfs-opt-inv.txt
# ../outputs/cpd/orz203d.map-3-dfs-c2.txt
# ../outputs/cpd/orz701d.map-3-dfs-c16-inv.txt
# ../outputs/cpd/AcrosstheCape.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz700d.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz200d.map-3-dfs-c2-inv.txt
# ../outputs/cpd/BlackLotus.map-3-dfs-c64.txt
# ../outputs/cpd/orz701d.map-3-dfs-c64-inv.txt
# ../outputs/cpd/AcrosstheCape.map-3-dfs-c16-inv.txt
# ../outputs/cpd/orz900d.map-3-dfs-c4.txt
# ../outputs/cpd/orz901d.map-3-dfs-c2.txt
# ../outputs/cpd/lt_warehouse_n.map-3-dfs-c16.txt
# ../outputs/cpd/ca_caverns2prc.map-3-dfs-c8.txt
# ../outputs/cpd/orz102d.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks_n.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks_a3_n.map-3-dfs-c64-inv.txt
# ../outputs/cpd/ht_mansion_n.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_warehouse_n.map-3-dfs-opt.txt
# ../outputs/cpd/ca_cave.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_hangedman.map-3-dfs-c64.txt
# ../outputs/cpd/lt_undercitydungeon.map-3-dfs-c4-inv.txt
# ../outputs/cpd/orz701d.map-3-dfs-c2-inv.txt
# ../outputs/cpd/orz702d.map-3-dfs-c2.txt
# ../outputs/cpd/lt_0_lowtown_a2.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz703d.map-3-dfs-c4.txt
# ../outputs/cpd/maze-100-1.map-3-dfs-c16-inv.txt
# ../outputs/cpd/ht_chantry.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_ruinedhouse_n.map-3-dfs-opt.txt
# ../outputs/cpd/w_bonepit.map-3-dfs-c2.txt
# ../outputs/cpd/lt_ruinedhouse_n.map-3-dfs-c16.txt
# ../outputs/cpd/lt_0_lowtown_a2.map-3-dfs-c4.txt
# ../outputs/cpd/orz301d.map-3-dfs-c32.txt
# ../outputs/cpd/lt_0_lowtown_docks_a3_n.map-3-dfs-c4.txt
# ../outputs/cpd/lt_ruinedhouse_n.map-3-dfs-c8.txt
# ../outputs/cpd/Backwoods.map-3-dfs-c2-inv.txt
# ../outputs/cpd/orz303d.map-3-dfs-c2-inv.txt
# ../outputs/cpd/room-400-40.map-3-dfs-c4.txt
# ../outputs/cpd/AcrosstheCape.map-3-dfs-c2.txt
# ../outputs/cpd/w_woundedcoast.map-3-dfs-c16.txt
# ../outputs/cpd/ht_keep.map-3-dfs-c32.txt
# ../outputs/cpd/orz200d.map-3-dfs-c64.txt
# ../outputs/cpd/w_woundedcoast.map-3-dfs-opt.txt
# ../outputs/cpd/lt_0_lowtown_n.map-3-dfs-c32-inv.txt
# ../outputs/cpd/ht_bartrand_n.map-3-dfs-c2-inv.txt
# ../outputs/cpd/Aftershock.map-3-dfs-c8-inv.txt
# ../outputs/cpd/random-100-33.map-3-dfs-c32-inv.txt
# ../outputs/cpd/ht_0_hightown.map-3-dfs-c8-inv.txt
# ../outputs/cpd/AcrosstheCape.map-3-dfs-c16.txt
# ../outputs/cpd/AcrosstheCape.map-3-dfs-opt.txt
# ../outputs/cpd/ca_cave.map-3-dfs-c2.txt
# ../outputs/cpd/AcrosstheCape.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_gamlenshouse_n.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_shop.map-3-dfs-c32.txt
# ../outputs/cpd/lt_0_lowtown_docks.map-3-dfs-c8-inv.txt
# ../outputs/cpd/dr_dungeon.map-3-dfs-opt-inv.txt
# ../outputs/cpd/orz302d.map-3-dfs-c64-inv.txt
# ../outputs/cpd/w_bonepit.map-3-dfs-c64-inv.txt
# ../outputs/cpd/room-100-10.map-3-dfs-c16-inv.txt
# ../outputs/cpd/orz303d.map-3-dfs-c32-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks_a3_n.map-3-dfs-c32.txt
# ../outputs/cpd/lt_0_lowtown_a3_n_c.map-3-dfs-c4-inv.txt
# ../outputs/cpd/random-100-33.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_0_lowtown.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz302d.map-3-dfs-c32.txt
# ../outputs/cpd/lt_backalley_g.map-3-dfs-c32-inv.txt
# ../outputs/cpd/lt_hangedman_n.map-3-dfs-c8.txt
# ../outputs/cpd/orz302d.map-3-dfs-c16-inv.txt
# ../outputs/cpd/w_bonepit.map-3-dfs-c16-inv.txt
# ../outputs/cpd/room-100-10.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz999d.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_hangedman_n.map-3-dfs-c32.txt
# ../outputs/cpd/lt_gamlenshouse_n.map-3-dfs-c64-inv.txt
# ../outputs/cpd/lt_0_lowtown_a2_n_c.map-3-dfs-opt.txt
# ../outputs/cpd/orz302d.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_undercitydungeon.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_0_lowtown_a2_n_c.map-3-dfs-c16.txt
# ../outputs/cpd/lt_0_lowtown_a2_n.map-3-dfs-c2.txt
# ../outputs/cpd/lt_ruinedhouse_n.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_warehouse.map-3-dfs-c64.txt
# ../outputs/cpd/ht_mansion_n.map-3-dfs-c16.txt
# ../outputs/cpd/orz103d.map-3-dfs-c4.txt
# ../outputs/cpd/orz201d.map-3-dfs-c4-inv.txt
# ../outputs/cpd/orz102d.map-3-dfs-c2.txt
# ../outputs/cpd/ht_mansion_n.map-3-dfs-opt.txt
# ../outputs/cpd/random-400-33.map-3-dfs-c2.txt
# ../outputs/cpd/ca_cave.map-3-dfs-c4-inv.txt
# ...
# ../outputs/cpd/orz304d.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_0_lowtown_a2_n_c.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_undercityserialkiller.map-3-dfs-c4.txt
# ../outputs/cpd/ht_playershouse_n.map-3-dfs-c8.txt
# ../outputs/cpd/w_encounter2_camp.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz500d.map-3-dfs-c2.txt
# ../outputs/cpd/ht_brothel_n.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_gallowstemplar_n.map-3-dfs-c2-inv.txt
# ../outputs/cpd/w_encounter1.map-3-dfs-opt.txt
# ../outputs/cpd/w_encounter1.map-3-dfs-c16.txt
# ../outputs/cpd/lt_warehouse.map-3-dfs-c4-inv.txt
# ../outputs/cpd/random-400-33.map-3-dfs-opt-inv.txt
# ../outputs/cpd/w_sundermount.map-3-dfs-c2.txt
# ../outputs/cpd/dr_primevaltomb.map-3-dfs-c64.txt
# ../outputs/cpd/Brushfire.map-3-dfs-c8.txt
# ../outputs/cpd/orz000d.map-3-dfs-c4.txt
# ../outputs/cpd/dr_slavers.map-3-dfs-c2.txt
# ../outputs/cpd/w_bonepitdestroyed_a3.map-3-dfs-opt-inv.txt
# ../outputs/cpd/w_encounter2_camp.map-3-dfs-c32.txt
# ../outputs/cpd/orz203d.map-3-dfs-c32-inv.txt
# ../outputs/cpd/random-100-33.map-3-dfs-c16.txt
# ../outputs/cpd/orz999d.map-3-dfs-c4.txt
# ../outputs/cpd/orz303d.map-3-dfs-c64.txt
# ../outputs/cpd/ht_brothel_n.map-3-dfs-c32.txt
# ../outputs/cpd/random-100-33.map-3-dfs-opt.txt
# ../outputs/cpd/orz304d.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz704d.map-3-dfs-c4.txt
# ../outputs/cpd/Archipelago.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_warehouse_n.map-3-dfs-c8.txt
# ../outputs/cpd/lt_gallowstemplar.map-3-dfs-opt.txt
# ../outputs/cpd/lt_gallowstemplar.map-3-dfs-c16.txt
# ../outputs/cpd/room-100-10.map-3-dfs-c32.txt
# ../outputs/cpd/Brushfire.map-3-dfs-c4-inv.txt
# ../outputs/cpd/ca_caverns1_mines.map-3-dfs-c4.txt
# ../outputs/cpd/orz703d.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_hangedman.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz200d.map-3-dfs-c16.txt
# ../outputs/cpd/orz200d.map-3-dfs-opt.txt
# ../outputs/cpd/w_woundedcoast.map-3-dfs-c64.txt
# ../outputs/cpd/orz300d.map-3-dfs-c4.txt
# ../outputs/cpd/orz301d.map-3-dfs-c2.txt
# ../outputs/cpd/AcrosstheCape.map-3-dfs-c64.txt
# ../outputs/cpd/lt_0_lowtown.map-3-dfs-c32-inv.txt
# ../outputs/cpd/w_bonepitdestroyed_a3.map-3-dfs-c2-inv.txt
# ../outputs/cpd/w_encounter2_camp.map-3-dfs-c4.txt
# ../outputs/cpd/orz304d.map-3-dfs-c32.txt
# ../outputs/cpd/w_blightlands.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_gallowscourtyard.map-3-dfs-c2-inv.txt
# ../outputs/cpd/lt_foundry_n.map-3-dfs-c8-inv.txt
# ../outputs/cpd/ht_0_hightown.map-3-dfs-c32-inv.txt
# ../outputs/cpd/room-100-10.map-3-dfs-c2-inv.txt
# ../outputs/cpd/ht_mansion2.map-3-dfs-c4.txt
# ../outputs/cpd/ca_caverns2.map-3-dfs-c64-inv.txt
# ../outputs/cpd/w_encounter1.map-3-dfs-c32-inv.txt
# ../outputs/cpd/w_encounter2_camp.map-3-dfs-c16-inv.txt
# ../outputs/cpd/Aurora.map-3-dfs-c32-inv.txt
# ../outputs/cpd/ca_caverns2.map-3-dfs-c16-inv.txt
# ../outputs/cpd/w_encounter2_camp.map-3-dfs-c64-inv.txt
# ../outputs/cpd/ht_mansion2b.map-3-dfs-c4.txt
# ../outputs/cpd/lt_shop.map-3-dfs-c32-inv.txt
# ../outputs/cpd/lt_darktown.map-3-dfs-c32-inv.txt
# ../outputs/cpd/ht_mansion2.map-3-dfs-opt-inv.txt
# ../outputs/cpd/orz105d.map-3-dfs-c4.txt
# ../outputs/cpd/lt_0_lowtown_a2_n_c.map-3-dfs-c64.txt
# ../outputs/cpd/w_blightlands.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz101d.map-3-dfs-c4-inv.txt
# ../outputs/cpd/ht_mansion_n.map-3-dfs-c64.txt
# ../outputs/cpd/lt_warehouse.map-3-dfs-c16.txt
# ../outputs/cpd/orz106d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/Backwoods.map-3-dfs-opt-inv.txt
# ../outputs/cpd/dr_dungeon.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_warehouse.map-3-dfs-opt.txt
# ../outputs/cpd/ht_chantry_n.map-3-dfs-c2.txt
# ../outputs/cpd/lt_gallowscourtyard.map-3-dfs-c32.txt
# ../outputs/cpd/dr_slavers.map-3-dfs-opt-inv.txt
# ../outputs/cpd/orz601d.map-3-dfs-c4.txt
# ../outputs/cpd/orz100d.map-3-dfs-opt-inv.txt
# ../outputs/cpd/Aftershock.map-3-dfs-c8.txt
# ../outputs/cpd/orz703d.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz702d.map-3-dfs-c32-inv.txt
# ../outputs/cpd/random-400-33.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_gamlenshouse_n.map-3-dfs-c32-inv.txt
# ../outputs/cpd/lt_undercityserialkiller.map-3-dfs-c16.txt
# ../outputs/cpd/orz100d.map-3-dfs-c32.txt
# ../outputs/cpd/lt_backalley_g.map-3-dfs-c64-inv.txt
# ../outputs/cpd/lt_undercityserialkiller.map-3-dfs-opt.txt
# ../outputs/cpd/ca_cavern1_haunted.map-3-dfs-c4-inv.txt
# ../outputs/cpd/room-100-10.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz303d.map-3-dfs-c16-inv.txt
# ../outputs/cpd/w_blightlands.map-3-dfs-c2.txt
# ../outputs/cpd/random-100-33.map-3-dfs-c16-inv.txt
# ../outputs/cpd/orz201d.map-3-dfs-c2.txt
# ../outputs/cpd/orz200d.map-3-dfs-c4.txt
# ../outputs/cpd/lt_0_lowtown_n.map-3-dfs-c16-inv.txt
# ../outputs/cpd/w_encounter2.map-3-dfs-c64.txt
# ../outputs/cpd/w_woundedcoast.map-3-dfs-c64-inv.txt
# ../outputs/cpd/room-400-40.map-3-dfs-c32.txt
# ../outputs/cpd/orz700d.map-3-dfs-opt.txt
# ../outputs/cpd/orz700d.map-3-dfs-c16.txt
# ../outputs/cpd/lt_0_lowtown_a2_n.map-3-dfs-c4-inv.txt
# ../outputs/cpd/BigGameHunters.map-3-dfs-c8-inv.txt
# ../outputs/cpd/lt_warehouse_n.map-3-dfs-c2-inv.txt
# ../outputs/cpd/orz303d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/Backwoods.map-3-dfs-c8-inv.txt
# ../outputs/cpd/Brushfire.map-3-dfs-opt-inv.txt
# ../outputs/cpd/orz701d.map-3-dfs-c4.txt
# ../outputs/cpd/orz700d.map-3-dfs-c2.txt
# ../outputs/cpd/ca_cavern1_haunted.map-3-dfs-c8.txt
# ../outputs/cpd/w_woundedcoast.map-3-dfs-c16-inv.txt
# ../outputs/cpd/ht_0_hightown_n.map-3-dfs-c64.txt
# ../outputs/cpd/ht_chantry_n.map-3-dfs-c32.txt
# ../outputs/cpd/lt_gallowstemplar_f.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_0_lowtown_n.map-3-dfs-c64-inv.txt
# ../outputs/cpd/random-100-33.map-3-dfs-c64-inv.txt
# ../outputs/cpd/w_woundedcoast.map-3-dfs-c8.txt
# ../outputs/cpd/w_bonepit.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz302d.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz303d.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz701d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz500d.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ht_keep.map-3-dfs-c4.txt
# ../outputs/cpd/lt_backalley_g.map-3-dfs-c16-inv.txt
# ../outputs/cpd/orz200d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz304d.map-3-dfs-c4-inv.txt
# ../outputs/cpd/ca_cavern1_haunted.map-3-dfs-c64.txt
# ../outputs/cpd/lt_gallowstemplar_n.map-3-dfs-c2.txt
# ../outputs/cpd/w_bonepitdestroyed_a3.map-3-dfs-c64.txt
# ../outputs/cpd/Aurora.map-3-dfs-c4.txt
# ../outputs/cpd/lt_0_lowtown_a2.map-3-dfs-c64-inv.txt
# ../outputs/cpd/Brushfire.map-3-dfs-c64.txt
# ../outputs/cpd/orz900d.map-3-dfs-c64.txt
# ../outputs/cpd/lt_gamlenshouse_n.map-3-dfs-c2.txt
# ../outputs/cpd/ht_0_hightown_a2.map-3-dfs-c64.txt
# ../outputs/cpd/orz700d.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz701d.map-3-dfs-c32-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks.map-3-dfs-c2-inv.txt
# ../outputs/cpd/ht_0_hightown_n.map-3-dfs-c4.txt
# ../outputs/cpd/orz703d.map-3-dfs-c16.txt
# ../outputs/cpd/ht_keep_n.map-3-dfs-c16.txt
# ../outputs/cpd/lt_0_lowtown_docks_a3_n.map-3-dfs-c32-inv.txt
# ../outputs/cpd/maze-400-4.map-3-dfs-c32.txt
# ../outputs/cpd/orz103d.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ht_keep_n.map-3-dfs-opt.txt
# ../outputs/cpd/orz703d.map-3-dfs-opt.txt
# ../outputs/cpd/ht_0_hightown.map-3-dfs-c2-inv.txt
# ../outputs/cpd/dr_slavers.map-3-dfs-c32.txt
# ../outputs/cpd/orz304d.map-3-dfs-c4.txt
# ../outputs/cpd/ht_bartrand_n.map-3-dfs-c16-inv.txt
# ../outputs/cpd/orz103d.map-3-dfs-c32.txt
# ../outputs/cpd/lt_backalley_g.map-3-dfs-c2.txt
# ../outputs/cpd/Aftershock.map-3-dfs-c2-inv.txt
# ../outputs/cpd/ht_bartrand_n.map-3-dfs-c8-inv.txt
# ../outputs/cpd/lt_0_lowtown_n.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_0_lowtown_a2.map-3-dfs-c64.txt
# ../outputs/cpd/lt_undercitydungeon.map-3-dfs-c4.txt
# ../outputs/cpd/Archipelago.map-3-dfs-c2.txt
# ../outputs/cpd/ht_bartrand_n.map-3-dfs-c64-inv.txt
# ../outputs/cpd/w_sundermount.map-3-dfs-c32.txt
# ../outputs/cpd/lt_darktown.map-3-dfs-c2.txt
# ../outputs/cpd/ht_0_hightown.map-3-dfs-c32.txt
# ../outputs/cpd/w_encounter1.map-3-dfs-c2.txt
# ../outputs/cpd/lt_0_lowtown_docks_a3.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks_n.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz700d.map-3-dfs-c16-inv.txt
# ../outputs/cpd/w_encounter2.map-3-dfs-c8.txt
# ../outputs/cpd/maze-400-4.map-3-dfs-c4.txt
# ../outputs/cpd/AcrosstheCape.map-3-dfs-c32-inv.txt
# ../outputs/cpd/ca_caverns1_mines.map-3-dfs-c16.txt
# ../outputs/cpd/random-400-33.map-3-dfs-c64.txt
# ../outputs/cpd/ca_caverns1_mines.map-3-dfs-opt.txt
# ../outputs/cpd/lt_gallowstemplar.map-3-dfs-c8.txt
# ../outputs/cpd/orz100d.map-3-dfs-c2.txt
# ../outputs/cpd/orz101d.map-3-dfs-c4.txt
# ../outputs/cpd/maze-100-1.map-3-dfs-c32-inv.txt
# ../outputs/cpd/Aftershock.map-3-dfs-c32.txt
# ../outputs/cpd/lt_0_lowtown_a2.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_0_lowtown.map-3-dfs-c2-inv.txt
# ../outputs/cpd/ca_caverns1.map-3-dfs-c64.txt
# ../outputs/cpd/maze-400-4.map-3-dfs-c2-inv.txt
# ../outputs/cpd/lt_hangedman.map-3-dfs-c4.txt
# ../outputs/cpd/orz301d.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz300d.map-3-dfs-c64-inv.txt
# ../outputs/cpd/lt_0_lowtown_a2_n_c.map-3-dfs-c16-inv.txt
# ../outputs/cpd/room-400-40.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ht_0_hightown_a3.map-3-dfs-c8.txt
# ../outputs/cpd/Archipelago.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_0_lowtown_docks.map-3-dfs-c2.txt
# ../outputs/cpd/ht_mansion2b.map-3-dfs-c4-inv.txt
# ../outputs/cpd/orz203d.map-3-dfs-opt.txt
# ../outputs/cpd/lt_backalley_n.map-3-dfs-c2-inv.txt
# ../outputs/cpd/orz203d.map-3-dfs-c16.txt
# ../outputs/cpd/orz500d.map-3-dfs-c4.txt
# ../outputs/cpd/lt_undercityserialkiller.map-3-dfs-c2.txt
# ../outputs/cpd/w_encounter3.map-3-dfs-c2-inv.txt
# ../outputs/cpd/Aurora.map-3-dfs-c2-inv.txt
# ../outputs/cpd/w_encounter1.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_hangedman.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_undercityserialkiller.map-3-dfs-c64-inv.txt
# ../outputs/cpd/lt_hangedman.map-3-dfs-c16.txt
# ../outputs/cpd/dr_slavers.map-3-dfs-c4.txt
# ../outputs/cpd/lt_warehouse_n.map-3-dfs-c64.txt
# ../outputs/cpd/lt_hangedman.map-3-dfs-opt.txt
# ../outputs/cpd/lt_undercityserialkiller.map-3-dfs-c16-inv.txt
# ../outputs/cpd/orz000d.map-3-dfs-c2.txt
# ../outputs/cpd/BlackLotus.map-3-dfs-c16.txt
# ../outputs/cpd/BlackLotus.map-3-dfs-opt.txt
# ../outputs/cpd/w_sundermount.map-3-dfs-c4.txt
# ../outputs/cpd/lt_undercityencounter.map-3-dfs-c32-inv.txt
# ../outputs/cpd/ht_0_hightown_a2.map-3-dfs-c2-inv.txt
# ../outputs/cpd/lt_warehouse.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz999d.map-3-dfs-c2.txt
# ../outputs/cpd/lt_darktown.map-3-dfs-c8-inv.txt
# ../outputs/cpd/Backwoods.map-3-dfs-c32.txt
# ../outputs/cpd/orz704d.map-3-dfs-c2.txt
# ../outputs/cpd/lt_ruinedhouse_n.map-3-dfs-c64.txt
# ../outputs/cpd/lt_gallowstemplar_n.map-3-dfs-opt-inv.txt
# ../outputs/cpd/orz100d.map-3-dfs-c2-inv.txt
# ../outputs/cpd/orz300d.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_0_lowtown_a2_n_c.map-3-dfs-c64-inv.txt
# ../outputs/cpd/lt_gamlenshouse_n.map-3-dfs-c2-inv.txt
# ../outputs/cpd/w_encounter2.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_darktown.map-3-dfs-c64.txt
# ../outputs/cpd/ca_caverns1_mines.map-3-dfs-c2.txt
# ../outputs/cpd/lt_undercityencounter.map-3-dfs-c64.txt
# ../outputs/cpd/ht_0_hightown_a3.map-3-dfs-c32-inv.txt
# ../outputs/cpd/w_encounter2_camp.map-3-dfs-c2.txt
# ../outputs/cpd/lt_warehouse_n.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz300d.map-3-dfs-c2.txt
# ../outputs/cpd/w_blightlands.map-3-dfs-c4-inv.txt
# ../outputs/cpd/orz301d.map-3-dfs-c4.txt
# ../outputs/cpd/ht_mansion2b.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_hangedman_n.map-3-dfs-c4-inv.txt
# ../outputs/cpd/orz601d.map-3-dfs-c64-inv.txt
# ../outputs/cpd/ht_chantry_n.map-3-dfs-c32-inv.txt
# ../outputs/cpd/ht_mansion2.map-3-dfs-c2.txt
# ../outputs/cpd/ht_bartrand_n.map-3-dfs-c32.txt
# ../outputs/cpd/ht_keep_n.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ht_mansion2b.map-3-dfs-c2.txt
# ../outputs/cpd/orz704d.map-3-dfs-c4-inv.txt
# ../outputs/cpd/BlastFurnace.map-3-dfs-opt-inv.txt
# ../outputs/cpd/lt_0_lowtown_a2.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_0_lowtown_a3_n_c.map-3-dfs-opt-inv.txt
# ../outputs/cpd/orz301d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz601d.map-3-dfs-c16-inv.txt
# ../outputs/cpd/orz105d.map-3-dfs-c2.txt
# ../outputs/cpd/ht_mansion2b.map-3-dfs-c64-inv.txt
# ../outputs/cpd/lt_gallowscourtyard_n.map-3-dfs-c4-inv.txt
# ../outputs/cpd/ca_caverns2.map-3-dfs-opt.txt
# ../outputs/cpd/ht_chantry_n.map-3-dfs-c4.txt
# ../outputs/cpd/ca_caverns2.map-3-dfs-c16.txt
# ../outputs/cpd/lt_0_lowtown_docks_n.map-3-dfs-c16.txt
# ../outputs/cpd/lt_0_lowtown_docks_n.map-3-dfs-opt.txt
# ../outputs/cpd/dr_primevalentrance.map-3-dfs-c32-inv.txt
# ../outputs/cpd/ca_caverns2prc.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz300d.map-3-dfs-c64.txt
# ../outputs/cpd/lt_house.map-3-dfs-c8.txt
# ../outputs/cpd/orz601d.map-3-dfs-c2.txt
# ../outputs/cpd/orz703d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/w_sundermount.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ca_caverns1_mines.map-3-dfs-c8-inv.txt
# ../outputs/cpd/BlastFurnace.map-3-dfs-c2-inv.txt
# ../outputs/cpd/orz702d.map-3-dfs-c32.txt
# ../outputs/cpd/ht_0_hightown_a3.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz999d.map-3-dfs-c16-inv.txt
# ../outputs/cpd/ht_0_hightown_n.map-3-dfs-c4-inv.txt
# ../outputs/cpd/Aftershock.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_gallowstemplar_f.map-3-dfs-opt-inv.txt
# ../outputs/cpd/w_encounter3.map-3-dfs-c64.txt
# ../outputs/cpd/lt_gallowscourtyard.map-3-dfs-c16-inv.txt
# ../outputs/cpd/lt_gallowstemplar_n.map-3-dfs-c64.txt
# ../outputs/cpd/ht_chantry.map-3-dfs-c8.txt
# ../outputs/cpd/w_encounter3.map-3-dfs-c32-inv.txt
# ../outputs/cpd/orz201d.map-3-dfs-c4.txt
# ../outputs/cpd/orz102d.map-3-dfs-c16.txt
# ../outputs/cpd/w_bonepitmining_a2.map-3-dfs-c8-inv.txt
# ../outputs/cpd/orz200d.map-3-dfs-c2.txt
# ../outputs/cpd/w_blightlands.map-3-dfs-c4.txt
# ../outputs/cpd/orz102d.map-3-dfs-opt.txt
# ../outputs/cpd/ca_caverns1_mines.map-3-dfs-c64-inv.txt
# ../outputs/cpd/ht_0_hightown_a2.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ht_keep_n.map-3-dfs-c8.txt
# ../outputs/cpd/orz900d.map-3-dfs-c8-inv.txt
# ../outputs/cpd/lt_gallowscourtyard_n.map-3-dfs-opt-inv.txt
# ../outputs/cpd/orz201d.map-3-dfs-c64-inv.txt
# ../outputs/cpd/orz200d.map-3-dfs-c32-inv.txt
# ../outputs/cpd/dr_primevalentrance.map-3-dfs-c16.txt
# ../outputs/cpd/dr_primevalentrance.map-3-dfs-opt.txt
# ../outputs/cpd/orz103d.map-3-dfs-c4-inv.txt
# ../outputs/cpd/ca_caverns2prc.map-3-dfs-c32.txt
# ../outputs/cpd/lt_backalley_n.map-3-dfs-c64.txt
# ../outputs/cpd/orz201d.map-3-dfs-c16-inv.txt
# ../outputs/cpd/orz701d.map-3-dfs-c2.txt
# ../outputs/cpd/orz700d.map-3-dfs-c4.txt
# ../outputs/cpd/ca_caverns1_mines.map-3-dfs-c16-inv.txt
# ../outputs/cpd/dr_0_deeproads.map-3-dfs-c32-inv.txt
# ../outputs/cpd/ht_chantry.map-3-dfs-c32.txt
# ../outputs/cpd/lt_gallowscourtyard.map-3-dfs-c64-inv.txt
# ../outputs/cpd/ht_keep.map-3-dfs-opt-inv.txt
# ../outputs/cpd/ht_keep.map-3-dfs-c2.txt
# ../outputs/cpd/ht_bartrand_n.map-3-dfs-c8.txt
# ../outputs/cpd/ht_mansion2.map-3-dfs-c32.txt
# ../outputs/cpd/lt_gallowsprison_n.map-3-dfs-c8.txt
# ../outputs/cpd/Aftershock.map-3-dfs-c64-inv.txt
# ../outputs/cpd/ca_caverns2.map-3-dfs-c2-inv.txt
# ../outputs/cpd/dr_primevalentrance.map-3-dfs-c4-inv.txt
# ../outputs/cpd/BigGameHunters.map-3-dfs-c32.txt
# ../outputs/cpd/lt_gallowscourtyard_n.map-3-dfs-c64.txt
# ../outputs/cpd/orz999d.map-3-dfs-c64-inv.txt
# ../outputs/cpd/w_woundedcoast.map-3-dfs-c8-inv.txt
# ../outputs/cpd/dr_0_deeproads.map-3-dfs-c16.txt
# ../outputs/cpd/orz000d.map-3-dfs-c4-inv.txt
# ../outputs/cpd/lt_gallowstemplar.map-3-dfs-c8-inv.txt
# ../outputs/cpd/dr_0_deeproads.map-3-dfs-opt.txt
# ../outputs/cpd/dr_0_deeproads.map-3-dfs-c8.txt
# ../outputs/cpd/w_encounter2.map-3-dfs-c8-inv.txt
# ../outputs/cpd/lt_gallowstemplar_n.map-3-dfs-c4.txt
# ../outputs/cpd/ht_store.map-3-dfs-opt-inv.txt
#            map  scenid     ratio  step-diff     diff  step-access  step-cost  \
# 0  lt_darktown       0  0.000000   0.000000  0.00000     0.250000  83.000000
# 1  lt_darktown       1  0.383215   0.299997  2.99997     0.300000  51.960000
# 2  lt_darktown       2  0.600892   0.444450  4.00005     0.444444  57.733333
# 3  lt_darktown       3  0.000000   0.000000  0.00000     0.250000  72.450000
# 4  lt_darktown       4  0.957107   0.546919  3.82843     0.285714  56.485714
#
#    tcost  distance   expect  steps  access  r     itype
# 0  332.0   4.00000  4.00000      4       1  4  backward
# 1  519.6  10.82840  7.82843     10       3  4  backward
# 2  519.6  10.65690  6.65685      9       4  4  backward
# 3  289.8   4.41421  4.41421      4       1  4  backward
# 4  395.4   7.82843  4.00000      7       2  4  backward

# %%
room = cpd[cpd['map'].apply(lambda x: mtype(x) == 'room')]
maze = cpd[cpd['map'].apply(lambda x: mtype(x) == 'maze')]
random = cpd[cpd['map'].apply(lambda x: mtype(x) == 'random')]
game = cpd[cpd['map'].apply(lambda x: mtype(x) == 'game')]

# %%
# load tree
prefix = "../outputs/tree/"
h = [prefix + i for i in os.listdir(prefix)]
tree = load_files(h)
tree.insert(2, "step-cost", tree['tcost'] / tree['steps'])
tree.insert(2, "diff", tree["distance"] - tree["expect"])
tree.insert(2, "step-diff", tree["diff"] / tree["steps"])
tree['d'] = 0
tree.head()
# Out:
# ../outputs/tree/maze-400-4.map.txt
# ../outputs/tree/w_encounter2.map.txt
# ../outputs/tree/orz601d.map.txt
# ../outputs/tree/BrokenSteppes.map.txt
# ../outputs/tree/ht_chantry_n.map.txt
# ../outputs/tree/ca_caverns1.map.txt
# ../outputs/tree/orz703d.map.txt
# ../outputs/tree/orz702d.map.txt
# ../outputs/tree/w_encounter2_camp.map.txt
# ../outputs/tree/Backwoods.map.txt
# ../outputs/tree/w_blightlands.map.txt
# ../outputs/tree/lt_gallowscourtyard.map.txt
# ../outputs/tree/orz107d.map.txt
# ../outputs/tree/orz106d.map.txt
# ../outputs/tree/lt_darktown.map.txt
# ../outputs/tree/lt_warehouse_n.map.txt
# ../outputs/tree/BigGameHunters.map.txt
# ../outputs/tree/dr_primevaltomb.map.txt
# ../outputs/tree/orz203d.map.txt
# ../outputs/tree/w_sundermount.map.txt
# ../outputs/tree/lt_undercityserialkiller.map.txt
# ../outputs/tree/w_encounter3.map.txt
# ../outputs/tree/lt_shop.map.txt
# ../outputs/tree/orz301d.map.txt
# ../outputs/tree/orz300d.map.txt
# ../outputs/tree/lt_gallowstemplar.map.txt
# ../outputs/tree/ht_chantry.map.txt
# ../outputs/tree/Aurora.map.txt
# ../outputs/tree/BlastFurnace.map.txt
# ../outputs/tree/Archipelago.map.txt
# ../outputs/tree/dr_0_deeproads.map.txt
# ../outputs/tree/lt_gallowstemplar_f.map.txt
# ../outputs/tree/room-400-40.map.txt
# ../outputs/tree/ca_caverns2.map.txt
# ../outputs/tree/ArcticStation.map.txt
# ../outputs/tree/lt_0_lowtown_docks_a3_n.map.txt
# ../outputs/tree/Aftershock.map.txt
# ../outputs/tree/random-100-33.map.txt
# ../outputs/tree/orz999d.map.txt
# ../outputs/tree/ht_playershouse_n.map.txt
# ../outputs/tree/lt_backalley_n.map.txt
# ../outputs/tree/w_bonepitmining_a2.map.txt
# ../outputs/tree/w_encounter1.map.txt
# ../outputs/tree/orz900d.map.txt
# ../outputs/tree/orz901d.map.txt
# ../outputs/tree/w_bonepit.map.txt
# ../outputs/tree/lt_backalley_g.map.txt
# ../outputs/tree/lt_gallowstemplar_n.map.txt
# ../outputs/tree/ht_mansion2.map.txt
# ../outputs/tree/lt_hangedman_n.map.txt
# ../outputs/tree/ht_0_hightown.map.txt
# ../outputs/tree/lt_0_lowtown_a2_n.map.txt
# ../outputs/tree/lt_gallowsprison_n.map.txt
# ../outputs/tree/orz704d.map.txt
# ../outputs/tree/lt_0_lowtown_a2_n_c.map.txt
# ../outputs/tree/room-100-10.map.txt
# ../outputs/tree/lt_0_lowtown_n.map.txt
# ../outputs/tree/AcrosstheCape.map.txt
# ../outputs/tree/ht_mansion2b.map.txt
# ../outputs/tree/orz100d.map.txt
# ../outputs/tree/orz101d.map.txt
# ../outputs/tree/lt_0_lowtown_docks_n.map.txt
# ../outputs/tree/w_woundedcoast.map.txt
# ../outputs/tree/ht_mansion_n.map.txt
# ../outputs/tree/orz302d.map.txt
# ../outputs/tree/orz303d.map.txt
# ../outputs/tree/ca_caverns2prc.map.txt
# ../outputs/tree/ca_caverns1_mines.map.txt
# ../outputs/tree/lt_0_lowtown_docks_a3.map.txt
# ../outputs/tree/ht_keep_n.map.txt
# ../outputs/tree/dr_primevalentrance.map.txt
# ../outputs/tree/orz200d.map.txt
# ../outputs/tree/orz201d.map.txt
# ../outputs/tree/dr_slavers.map.txt
# ../outputs/tree/Brushfire.map.txt
# ../outputs/tree/orz700d.map.txt
# ../outputs/tree/orz701d.map.txt
# ../outputs/tree/ca_cavern1_haunted.map.txt
# ../outputs/tree/lt_house.map.txt
# ../outputs/tree/orz105d.map.txt
# ../outputs/tree/random-400-33.map.txt
# ../outputs/tree/BlackLotus.map.txt
# ../outputs/tree/lt_0_lowtown_a2.map.txt
# ../outputs/tree/lt_undercitydungeon.map.txt
# ../outputs/tree/ht_0_hightown_a3.map.txt
# ../outputs/tree/lt_hangedman.map.txt
# ../outputs/tree/dr_dungeon.map.txt
# ../outputs/tree/lt_undercityencounter.map.txt
# ../outputs/tree/lt_0_lowtown_a3_n_c.map.txt
# ../outputs/tree/orz103d.map.txt
# ../outputs/tree/orz102d.map.txt
# ../outputs/tree/ht_bartrand_n.map.txt
# ../outputs/tree/ht_0_hightown_n.map.txt
# ../outputs/tree/maze-100-1.map.txt
# ../outputs/tree/ht_brothel_n.map.txt
# ../outputs/tree/lt_0_lowtown.map.txt
# ../outputs/tree/lt_gamlenshouse_n.map.txt
# ../outputs/tree/lt_0_lowtown_docks.map.txt
# ../outputs/tree/ht_store.map.txt
# ../outputs/tree/lt_gallowscourtyard_n.map.txt
# ../outputs/tree/ca_cave.map.txt
# ../outputs/tree/orz000d.map.txt
# ../outputs/tree/lt_warehouse.map.txt
# ../outputs/tree/orz304d.map.txt
# ../outputs/tree/lt_ruinedhouse_n.map.txt
# ../outputs/tree/ht_keep.map.txt
# ../outputs/tree/orz500d.map.txt
# ../outputs/tree/lt_foundry_n.map.txt
# ../outputs/tree/ht_0_hightown_a2.map.txt
# ../outputs/tree/w_bonepitdestroyed_a3.map.txt
# ../outputs/tree/orz800d.map.txt
#           map  scenid  step-diff        diff  step-cost   tcost   distance  \
# 0  maze-400-4       0   1.070364   364.99399   6.328446  2158.0   369.4082
# 1  maze-400-4       1   0.569030     6.82836  13.166667   158.0    13.0710
# 2  maze-400-4       2   0.438943     4.82837  14.036364   154.4    11.6568
# 3  maze-400-4       3   1.114376  1933.44320   5.669625  9836.8  1939.4432
# 4  maze-400-4       4   1.108682  1612.02316   5.192297  7549.6  1618.2658
#
#     expect  steps  d itype
# 0  4.41421    341  0  tree
# 1  6.24264     12  0  tree
# 2  6.82843     11  0  tree
# 3  6.00000   1735  0  tree
# 4  6.24264   1454  0  tree

# %%
# load focal
prefix = "../outputs/focal/"
h = [prefix + i for i in os.listdir(prefix)]
focal = load_files(h)
focal.insert(2, "step-cost", focal['tcost'] / focal['steps'])
focal.insert(2, "diff", focal["distance"] - focal["expect"])
focal.insert(2, "step-diff", focal["diff"] / focal["steps"])
focal.insert(2, 'itype', 'focal')
focal.head()
# Out:
# ../outputs/focal/room-100-10-32.txt
# ../outputs/focal/ca_cavern1_haunted-8.txt
# ../outputs/focal/random-100-33-4.txt
# ../outputs/focal/room-100-10-8.txt
# ../outputs/focal/random-100-33-64.txt
# ../outputs/focal/random-100-33-0.txt
# ../outputs/focal/maze-100-1-16.txt
# ../outputs/focal/orz300d-8.txt
# ../outputs/focal/Archipelago-64.txt
# ../outputs/focal/Archipelago-16.txt
# ../outputs/focal/maze-100-1-0.txt
# ../outputs/focal/random-100-33-16.txt
# ../outputs/focal/ca_cavern1_haunted-32.txt
# ../outputs/focal/maze-100-1-64.txt
# ../outputs/focal/Archipelago-8.txt
# ../outputs/focal/orz300d-32.txt
# ../outputs/focal/maze-100-1-4.txt
# ../outputs/focal/orz300d-16.txt
# ../outputs/focal/room-100-10-64.txt
# ../outputs/focal/maze-100-1-8.txt
# ../outputs/focal/Archipelago-4.txt
# ../outputs/focal/random-100-33-32.txt
# ../outputs/focal/ca_cavern1_haunted-16.txt
# ../outputs/focal/Archipelago-0.txt
# ../outputs/focal/Archipelago-32.txt
# ../outputs/focal/ca_cavern1_haunted-0.txt
# ../outputs/focal/room-100-10-0.txt
# ../outputs/focal/ca_cavern1_haunted-64.txt
# ../outputs/focal/maze-100-1-32.txt
# ../outputs/focal/orz300d-4.txt
# ../outputs/focal/orz300d-0.txt
# ../outputs/focal/random-100-33-8.txt
# ../outputs/focal/room-100-10-4.txt
# ../outputs/focal/orz300d-64.txt
# ../outputs/focal/room-100-10-16.txt
# ../outputs/focal/ca_cavern1_haunted-4.txt
#            map  scenid  itype  step-diff      diff     step-cost     tcost  \
# 0  room-100-10       0  focal   0.000000   0.00000  51022.000000  306132.0
# 1  room-100-10       1  focal   0.165686   0.82843  29659.000000  148295.0
# 2  room-100-10       2  focal   0.922312  21.21317    237.547826    5463.6
# 3  room-100-10       3  focal   0.165684   0.82842    335.040000    1675.2
# 4  room-100-10       4  focal   0.000000   0.00000  35677.000000  214062.0
#
#    distance   expect  steps   r
# 0   6.65685  6.65685      6  32
# 1   5.24264  4.41421      5  32
# 2  29.04160  7.82843     23  32
# 3   5.65685  4.82843      5  32
# 4   6.65685  6.65685      6  32

# %%
def group_cpd(cpd_df, group=["itype", "r"], index=['map', 'scenid'], col='tcost'):
    gr_cpd = cpd_df.groupby(group)
    columns = group + index + [col]
    tmps = []
    keys = sorted(gr_cpd.groups.keys())
    for k in keys:
        d = gr_cpd.get_group(k)[columns]
        tmps.append(d.rename(columns={col: "%s-%s" % (col, '-'.join([str(i) for i in k]))}).drop(columns=group).set_index(index))
    from functools import reduce
    return reduce(lambda df1, df2: df1.join(df2, on=index), tmps)

# %%
# plot backward tcost
xs, ys, labels, ylim = [], [], [], [0.001, 40]
col, itype = 'tcost', 'backward'
t = group_cpd(cpd, col=col)
k0 = '%s-forward-0' % col
for i in [2, 4, 8, 16, 32, 64]:
    k = '%s-%s-%d' % (col, itype, i)
    xs.append(range(t[k].size))
    ys.append(sorted(t[k0].values / t[k].values))
    labels.append('%s-%d' % (itype, i))
plot_graph(xlabel='all scenarios', ylabel='time: fwd0 vs bwd-c', xs=xs, ys=ys,yscale='log', ylim=ylim,
           labels=labels, saveto='../analysis/pics/time-fwd0-bwdc.png')

# %%
cpd.groupby(['r', 'itype'])['step-cost'].describe().drop(columns='count').round(2)
# Out:
#               mean    std    min    25%    50%    75%      max
# r  itype
# 0  backward  29.26  25.34   5.17  14.95  22.69  33.03  1528.84
#    forward   42.96  33.04  12.21  24.87  31.08  44.16  1014.31
# 2  backward  28.55  25.47   5.75  15.03  22.43  31.82  2106.57
#    forward   42.22  31.42  12.57  25.10  31.02  43.47   786.08
# 4  backward  25.63  20.02   5.09  14.18  21.09  29.33   675.80
#    forward   39.85  28.30  12.47  24.67  30.08  40.97  1729.73
# 8  backward  23.23  16.90   5.36  13.50  19.08  26.82   786.31
#    forward   36.55  22.80  12.54  23.81  29.04  39.12   482.15
# 16 backward  21.92  14.75   4.94  13.03  18.26  25.56   550.01
#    forward   34.21  19.98  12.16  23.11  28.07  35.80   393.81
# 32 backward  21.11  30.48   4.88  12.94  17.88  24.61  9705.88
#    forward   31.42  16.31  11.43  22.38  26.59  32.98   456.60
# 64 backward  19.86  12.74   5.14  12.78  17.41  23.35  2564.23
#    forward   29.62  14.23   9.17  21.61  25.60  31.45   337.06

# %%
# plot backward tcost room maps
xs, ys, labels, ylim = [], [], [], [0.001, 40]
col, itype = 'tcost', 'backward'
t = group_cpd(room, col=col)
k0 = '%s-forward-0' % col
for i in [2, 4, 8, 16, 32, 64]:
    k = '%s-%s-%d' % (col, itype, i)
    xs.append(range(t[k].size))
    ys.append(sorted(t[k0].values / t[k].values))
    labels.append('%s-%d' % (itype, i))
plot_graph(xlabel='all scenarios', ylabel='time: fwd0 vs bwd-c', xs=xs, ys=ys, ylim=ylim,
           labels=labels, saveto='../analysis/pics/time-room-fwd0-bwdc.png')

# %%
# plot backward tcost room maps
xs, ys, labels, ylim = [], [], [], [0.001, 40]
col, itype = 'tcost', 'backward'
t = group_cpd(maze, col=col)
k0 = '%s-forward-0' % col
for i in [2, 4, 8, 16, 32, 64]:
    k = '%s-%s-%d' % (col, itype, i)
    xs.append(range(t[k].size))
    ys.append(sorted(t[k0].values / t[k].values))
    labels.append('%s-%d' % (itype, i))
plot_graph(xlabel='all scenarios', ylabel='time: fwd0 vs bwd-c', xs=xs, ys=ys, ylim=ylim,
           labels=labels, saveto='../analysis/pics/time-maze-fwd0-bwdc.png')

# %%
# plot backward tcost random maps
xs, ys, labels, ylim = [], [], [], [0.001, 40]
col, itype = 'tcost', 'backward'
t = group_cpd(random, col=col)
k0 = '%s-forward-0' % col
for i in [2, 4, 8, 16, 32, 64]:
    k = '%s-%s-%d' % (col, itype, i)
    xs.append(range(t[k].size))
    ys.append(sorted(t[k0].values / t[k].values))
    labels.append('%s-%d' % (itype, i))
plot_graph(xlabel='all scenarios', ylabel='time: fwd0 vs bwd-c', xs=xs, ys=ys, ylim=ylim,
           labels=labels, saveto='../analysis/pics/time-random-fwd0-bwdc.png')

# %%
# plot backward tcost game maps
xs, ys, labels, ylim = [], [], [], [0.001, 40]
col, itype = 'tcost', 'backward'
t = group_cpd(game, col=col)
k0 = '%s-forward-0' % col
for i in [2, 4, 8, 16, 32, 64]:
    k = '%s-%s-%d' % (col, itype, i)
    xs.append(range(t[k].size))
    ys.append(sorted(t[k0].values / t[k].values))
    labels.append('%s-%d' % (itype, i))
plot_graph(xlabel='all scenarios', ylabel='time: fwd0 vs bwd-c', xs=xs, ys=ys, ylim=ylim,
           labels=labels, saveto='../analysis/pics/time-game-fwd0-bwdc.png')

# %%
def vary_r_cpd(cpd_df, index=['map', 'itype'], col='tcost'):
    gr_cpd = cpd_df.groupby("r")
    tmps = []
    keys = sorted(gr_cpd.groups.keys())
    for k in keys:
        d = gr_cpd.get_group(k)[index + [col]]
        tmps.append(d.groupby(index).median().rename(columns={col: "%s-%d" % (col, k)}))
    from functools import reduce
    return reduce(lambda df1, df2: df1.join(df2, on=index), tmps)

# %%
vary_r_cpd(focal, col='tcost').round(6)
# Out:
#                             tcost-0    tcost-4     tcost-8    tcost-16  \
# map                itype
# Archipelago        focal  3336185.0  9468965.0  14121700.0  25790000.0
# ca_cavern1_haunted focal  1118900.0  2493775.0   3743165.0   8303395.0
# maze-100-1         focal   185326.0   237849.5    229138.5    223721.5
# orz300d            focal  1555325.0  4242410.0   6543325.0  13258600.0
# random-100-33      focal   180919.0   284043.5    414015.5    728793.0
# room-100-10        focal   179629.5   339771.5    502317.0    858621.5
#
#                             tcost-32    tcost-64
# map                itype
# Archipelago        focal  45220950.0  79412950.0
# ca_cavern1_haunted focal  19590700.0  45100200.0
# maze-100-1         focal    212204.5    202921.0
# orz300d            focal  27549750.0  60065550.0
# random-100-33      focal   1218760.0   1148975.0
# room-100-10        focal   1208495.0   2430275.0

# %%
cpd.groupby(["r", "itype"])["step-cost"].describe().drop(columns=['count'])
# Out:
#                   mean        std        min        25%        50%        75%  \
# r  itype
# 0  backward  29.262104  25.339716   5.174803  14.945694  22.686014  33.031026
#    forward   42.963124  33.043269  12.206452  24.865989  31.078754  44.164811
# 2  backward  28.553835  25.471171   5.747059  15.028246  22.433415  31.821356
#    forward   42.221370  31.420649  12.573714  25.100322  31.023809  43.470455
# 4  backward  25.628229  20.024018   5.090196  14.181922  21.093991  29.327436
#    forward   39.852905  28.301581  12.471642  24.667859  30.083611  40.971147
# 8  backward  23.230723  16.896004   5.361702  13.495085  19.076807  26.823006
#    forward   36.545388  22.804593  12.538983  23.810863  29.037163  39.115449
# 16 backward  21.920294  14.753907   4.940741  13.031887  18.255387  25.562777
#    forward   34.211681  19.980726  12.161864  23.108973  28.071999  35.795480
# 32 backward  21.112571  30.480607   4.879630  12.938617  17.879138  24.611670
#    forward   31.421825  16.312251  11.430769  22.376057  26.591689  32.983494
# 64 backward  19.855597  12.741665   5.139535  12.777801  17.408720  23.350131
#    forward   29.620180  14.232866   9.165385  21.606850  25.600000  31.454235
#
#                      max
# r  itype
# 0  backward  1528.844444
#    forward   1014.314286
# 2  backward  2106.571429
#    forward    786.080000
# 4  backward   675.800000
#    forward   1729.726667
# 8  backward   786.314286
#    forward    482.146667
# 16 backward   550.007143
#    forward    393.814286
# 32 backward  9705.884058
#    forward    456.600000
# 64 backward  2564.231939
#    forward    337.061111

# %%
cpd.head()
# Out:
#            map  scenid     ratio  step-diff     diff  step-access  step-cost  \
# 0  lt_darktown       0  0.000000   0.000000  0.00000     0.250000  83.000000
# 1  lt_darktown       1  0.383215   0.299997  2.99997     0.300000  51.960000
# 2  lt_darktown       2  0.600892   0.444450  4.00005     0.444444  57.733333
# 3  lt_darktown       3  0.000000   0.000000  0.00000     0.250000  72.450000
# 4  lt_darktown       4  0.957107   0.546919  3.82843     0.285714  56.485714
#
#    tcost  distance   expect  steps  access  r     itype
# 0  332.0   4.00000  4.00000      4       1  4  backward
# 1  519.6  10.82840  7.82843     10       3  4  backward
# 2  519.6  10.65690  6.65685      9       4  4  backward
# 3  289.8   4.41421  4.41421      4       1  4  backward
# 4  395.4   7.82843  4.00000      7       2  4  backward

# %%
b = cpd[cpd['itype'] == 'backward'].sort_values('access')

# %%
xs, ys = [], []
xs.append(sorted(b['steps']))
ys.append(sorted(b['steps']))

xs.append(sorted(b['st']))
plt.plot(sorted(b['steps']), sorted(b['steps']))
plt.plot(sorted(b['steps']), sorted(b['access']))

# %%
d = cpd.groupby(['r', 'itype'])

# %%
vary_r_cpd(tree.rename(columns={'d':'r'}), col='step-cost').round(6)
# Out:
#                           step-cost-0
# map                itype
# Archipelago        tree      6.201177
# ca_cavern1_haunted tree      6.616495
# maze-100-1         tree      7.799085
# orz300d            tree      6.714871
# random-100-33      tree      8.132515
# room-100-10        tree      9.063380

# %%
t = vary_r_cpd(cpd, col='step-diff')

# %%
vary_r_cpd(focal, col='step-cost').round(6)
# Out:
#                           step-cost-0   step-cost-4   step-cost-8  \
# map                itype
# Archipelago        focal  9280.962899  27480.910976  39643.344982
# ca_cavern1_haunted focal  2782.320641   6110.609334   9192.666028
# maze-100-1         focal   334.088668    426.220870    411.247092
# orz300d            focal  6504.384793  18338.950721  28080.040870
# random-100-33      focal  1878.645161   2969.791661   4259.849413
# room-100-10        focal  2263.907502   4200.241667   5861.072495
#
#                           step-cost-16   step-cost-32   step-cost-64
# map                itype
# Archipelago        focal  72953.788802  135258.219880  255254.545455
# ca_cavern1_haunted focal  20183.250916   46379.554929  111895.728435
# maze-100-1         focal    397.715667     380.328485     362.768198
# orz300d            focal  55667.080056  125319.091945  296442.828598
# random-100-33      focal   7671.823398   12059.679234   10970.030800
# room-100-10        focal  10553.007792   15909.923077   24219.572776

# %%
size = load_size("../analysis/size_all.txt")
size['size'] = size['size'].astype(float)

# %%
maze_sz = size[size['map'].apply(lambda x: mtype(x) == 'maze')]
room_sz = size[size['map'].apply(lambda x: mtype(x) == 'room')]
random_sz = size[size['map'].apply(lambda x: mtype(x) == 'random')]
game_sz = size[size['map'].apply(lambda x: mtype(x) == 'game')]

# %%
def vary_r_size(size_df, index=['map']):
    gr_size = size_df.groupby(["r", "itype"])
    tmps = []
    keys = sorted(gr_size.groups.keys())
    for k in keys:
        d = gr_size.get_group(k)
        tmps.append(d.rename(columns={'size': "size-%s-%d" % (k[1], k[0])}).drop(columns=['r', 'itype']).set_index(index))
    from functools import reduce
    return reduce(lambda df1, df2: df1.join(df2, on=index), tmps)

# %%
t = vary_r_size(size) / 1000000

# %%
t.head()
# Out:
#                size-backward-0  size-forward-0  size-backward-2  \
# map
# AcrosstheCape      5090.085074       95.462222      1302.419770
# Aftershock          926.308002        9.344258       241.359282
# Archipelago        1031.397234       36.148714       266.899022
# ArcticStation      5261.512962       35.919054      1359.436538
# Aurora            10162.892110      342.281118      2663.074330
#
#                size-forward-2  size-backward-4  size-forward-4  \
# map
# AcrosstheCape       89.949854       650.157446       63.263818
# Aftershock           9.699078       119.409102        8.716406
# Archipelago         34.299630       131.547794       23.391158
# ArcticStation       36.123678       677.099282       29.190590
# Aurora             305.910554      1326.776974      223.911362
#
#                size-backward-8  size-forward-8  size-backward-16  \
# map
# AcrosstheCape       183.377386       48.077898         67.514550
# Aftershock           35.461786        7.918466         13.765010
# Archipelago          38.262610       16.698542         14.886994
# ArcticStation       198.073694       24.005034         73.144414
# Aurora              380.866946      147.189882        133.771346
#
#                size-forward-16  size-backward-32  size-forward-32  \
# map
# AcrosstheCape        38.151606         22.964306        27.709694
# Aftershock            7.350954          5.636438         6.801718
# Archipelago          13.256686          5.677914         9.216242
# ArcticStation        20.559046         24.875338        17.849394
# Aurora               97.650054         43.403050        63.019106
#
#                size-backward-64  size-forward-64
# map
# AcrosstheCape         10.058082        21.768330
# Aftershock             3.104614         6.359210
# Archipelago            2.944162         7.214570
# ArcticStation         10.691194        16.125686
# Aurora                17.071318        45.250462

# %%
xs, ys, labels = [], [], []
k0 = 'size-forward-0'
for i in [0, 2, 4, 8, 16, 32, 64]:
    for j in ["backward"]:
        k = 'size-%s-%d' % (j, i)
        xs.append(range(t[k].size))
        ys.append(sorted(t[k0].values / t[k].values))
        labels.append('%s-%d' % ("rev", i))

plot_graph(xlabel='111 instances', ylabel='fwd-0 vs rev-c', xs=xs, ys=ys, 
           labels=labels, ylim=[0.001, 10], saveto='./pics/fwd0-bwd.png')

# %%
xs, ys, labels = [], [], []
k0 = 'size-forward-0'
for i in [0, 2, 4, 8, 16, 32, 64]:
    for j in ["forward"]:
        k = 'size-%s-%d' % (j, i)
        xs.append(range(t[k].size))
        ys.append(sorted(t[k0].values / t[k].values))
        labels.append('%s-%d' % ("fwd", i))

plot_graph(xlabel='111 instances', ylabel='fwd-0 vs fwd-c', xs=xs, ys=ys,
           labels=labels, saveto='./pics/fwd0-fwd.png', yscale='linear')

# %%
xs, ys, labels = [], [], []
for i in [0, 2, 4, 8, 16, 32, 64]:
    for j in ["backward"]:
        k0 = 'size-forward-%d' % i
        k = 'size-%s-%d' % (j, i)
        xs.append(range(t[k].size))
        ys.append(sorted(t[k0].values / t[k].values))
        labels.append('%s-%d' % ("rev", i))

plot_graph(xlabel='111 instances', ylabel='fwd-c vs reverse-c', xs=xs, ys=ys, 
           labels=labels, ylim=[0.001, 10], saveto='./pics/fwd-bwd.png')

# %%
(vary_r_size(maze_sz).T / 1000000).round(2)
# Out:
# map               maze-100-1  maze-400-4
# size-backward-0         9.68     3883.68
# size-forward-0          0.14        4.16
# size-backward-2         4.88     1214.90
# size-forward-2          0.15        4.57
# size-backward-4         2.50      491.22
# size-forward-4          0.15        4.42
# size-backward-8         1.32      192.70
# size-forward-8          0.15        4.21
# size-backward-16        0.71       72.61
# size-forward-16         0.15        4.00
# size-backward-32        0.37       31.72
# size-forward-32         0.14        3.85
# size-backward-64        0.21       14.61
# size-forward-64         0.14        3.71

# %%
(vary_r_size(room_sz).T / 1000000).round(2)
# Out:
# map               room-100-10  room-400-40
# size-backward-0         20.75      2161.59
# size-forward-0           1.07        74.40
# size-backward-2          6.36       567.15
# size-forward-2           0.91        67.12
# size-backward-4          2.79       260.98
# size-forward-4           0.73        44.90
# size-backward-8          1.07        72.23
# size-forward-8           0.55        29.66
# size-backward-16         0.45        25.30
# size-forward-16          0.42        20.07
# size-backward-32         0.24         8.57
# size-forward-32          0.35        12.63
# size-backward-64         0.13         3.64
# size-forward-64          0.26         8.48

# %%
(vary_r_size(random_sz).T / 1000000).round(2)
# Out:
# map               random-100-33  random-400-33
# size-backward-0           19.33        5323.83
# size-forward-0             0.62          41.14
# size-backward-2            7.67        2098.43
# size-forward-2             0.57          35.34
# size-backward-4            3.92        1062.38
# size-forward-4             0.50          29.97
# size-backward-8            1.83         465.17
# size-forward-8             0.42          23.64
# size-backward-16           0.87         198.86
# size-forward-16            0.35          18.12
# size-backward-32           0.45          95.15
# size-forward-32            0.30          14.09
# size-backward-64           0.19          45.45
# size-forward-64            0.22          10.32

# %%
with open("../analysis/cnums.txt", "r") as f:
    lines = f.readlines()

rows = []
for line in lines:
    fname, num = line.strip().split(',')
    data = parse_index_name(fname)
    rows.append([data['map'], data['r'], int(num)])
cnum = pd.DataFrame.from_records(rows, columns=['map', 'r', 'size'])
cnum.head()
# Out:
#              map   r    size
# 0  AcrosstheCape   0  392287
# 1  AcrosstheCape   2  100130
# 2  AcrosstheCape   4   49825
# 3  AcrosstheCape   8   13833
# 4  AcrosstheCape  16    4900

# %%
cnumgr = cnum.groupby('map')

# %%
t = (cnum.set_index(['map','r']).unstack(level=0).T).reset_index().drop(columns='level_0')

# %%
maplist = [
    'room-100-10', 'room-400-40', 
    'room-100-33', 'random-400-33',
    'maze-100-1', 'maze-400-4', 
    'Aurora', 'orz103d']
t[t['map'].apply(lambda x: x in maplist)].sort_values('map')
# Out:
# r              map       0       2      4      8    16    32   64
# 4           Aurora  493772  129509  64429  18485  6405  1981  697
# 68      maze-100-1    4999    2500   1264    656   336   162   80
# 69      maze-400-4  127996   40000  16143   6302  2343   995  431
# 74         orz103d   40392   11411   5468   1928   723   249  111
# 98   random-400-33  103535   40792  20640   9023  3844  1827  860
# 99     room-100-10    8261    2500   1074    389   140    56   12
# 100    room-400-40  152811   40000  18325   4980  1660   472  130

# %%
size.head()
# Out:
#              map     itype   r          size
# 0  AcrosstheCape   forward  16  3.815161e+07
# 1  AcrosstheCape  backward  16  6.751455e+07
# 2  AcrosstheCape   forward   2  8.994985e+07
# 3  AcrosstheCape  backward   2  1.302420e+09
# 4  AcrosstheCape   forward  32  2.770969e+07

# %%
t = size[(size['itype'] == 'backward') & size['map'].apply(lambda x: x in maplist)].drop(columns=['itype'])

# %%
print( (t.set_index(['map','r']).unstack(level=0) / 1000000).round(2).T.reset_index().drop(columns=['level_0']).to_latex() )
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# r &            map &         0 &        2 &        4 &       8 &      16 &     32 &     64 \\
# \midrule
# 0 &         Aurora &  10162.89 &  2663.07 &  1326.78 &  380.87 &  133.77 &  43.40 &  17.07 \\
# 1 &     maze-100-1 &      9.68 &     4.88 &     2.50 &    1.32 &    0.71 &   0.37 &   0.21 \\
# 2 &     maze-400-4 &   3883.68 &  1214.90 &   491.22 &  192.70 &   72.61 &  31.72 &  14.61 \\
# 3 &        orz103d &    179.06 &    51.00 &    24.69 &    9.03 &    3.69 &   1.59 &   0.98 \\
# 4 &  random-400-33 &   5323.83 &  2098.43 &  1062.38 &  465.17 &  198.86 &  95.15 &  45.45 \\
# 5 &    room-100-10 &     20.75 &     6.36 &     2.79 &    1.07 &    0.45 &   0.24 &   0.13 \\
# 6 &    room-400-40 &   2161.59 &   567.15 &   260.98 &   72.23 &   25.30 &   8.57 &   3.64 \\
# \bottomrule
# \end{tabular}

# %%
with open("../analysis/pure-size.txt", "r") as f:
    lines = f.readlines()

rows = []
for line in lines:
    num, fname = line.strip().split('\t')
    fname = fname.replace("-pure-", "-").replace("index_data/", "").replace("-pure", "")
    data = parse_index_name(fname)
    rows.append([data['map'], data['r'], data['itype'], int(num)])
pure = pd.DataFrame.from_records(rows, columns=['map', 'r', 'itype', 'size'])
pure.head()
# Out:
#       map   r     itype        size
# 0  Aurora  16   forward    97650054
# 1  Aurora  16  backward   476221874
# 2  Aurora   2   forward   305910554
# 3  Aurora   2  backward  9771734258
# 4  Aurora  32   forward    63019106

# %%
x = (pure[pure['itype']=='backward'].drop(columns=['itype']).set_index(['map','r']).unstack(level=0).T / 1000000).round(2)

# %%
print(x.reset_index().drop(columns=['level_0']).to_latex())
# Out:
# \begin{tabular}{llrrrrrrr}
# \toprule
# r &            map &        0 &        2 &        4 &        8 &      16 &      32 &      64 \\
# \midrule
# 0 &         Aurora &      NaN &  9771.73 &  4860.59 &  1384.69 &  476.22 &  143.81 &   47.05 \\
# 1 &     maze-400-4 &  7909.59 &  2473.07 &   998.97 &   390.93 &  146.32 &   63.02 &   28.17 \\
# 2 &        orz103d &   503.80 &   142.74 &    68.67 &    24.53 &    9.51 &    3.60 &    1.87 \\
# 3 &  random-400-33 &      NaN &  6408.98 &  3243.44 &  1418.59 &  605.10 &  288.30 &  136.44 \\
# 4 &    room-400-40 &  3190.34 &   836.35 &   384.35 &   105.75 &   36.49 &   11.78 &    4.51 \\
# \bottomrule
# \end{tabular}
